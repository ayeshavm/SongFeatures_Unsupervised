# %% [markdown]
# # Pop and Country Songs Analysis:
#
# ### Background:
#
# Music information retrieval. Music information retrieval (MIR) is the interdisciplinary science of retrieving information from music. MIR is a small but growing field of research with many real-world applications.
#
# There are several literatures about song genres and the different characteristics which define songs and genre.
# For this project we will specifically look at the song features:  Arousal, Valence, and Depth from the write up by [McGill University](https://phys.org/news/2016-05-scientists-categorize-music.html), and [this](https://phys.org/news/2016-05-scientists-categorize-music.html). They found that characteristics from a signle genre could be grouped in these same three categories.
#
# __The following song features or characteristics were defined as as:__<br>
# <br>Arousal - describes intensity and energy in music
# <br>Valence - describes the spectrum of emotions in music
# <br>Depth - describes intellect and sophistication in music
#
# <br>For this project, we will be extracting Spotify Features and Lyrics Text from Genius, the following data will be used:
#
# - Energy
# - Valence
# - Flesch Kincaid Grade:  this will be computed from the song lyrics text.  We will use this grade as our 'Intellect' feature
#
# For this project, we will be analyzing songs which have been tagged with the word 'pop' or 'country' from the Million Songs Database https://labrosa.ee.columbia.edu/millionsong/.
#
# and in the end specifically explore if there are differences between Taylor Swift's pre-pop - country songs and her pop songs.
#
#
# ### Problem Definition:
#
# - How does country and pop music differ?
# - Are there differences between the two music genres?
# - can we find some patterns that would differentiate these two music genres? (features, and themes - lyrics)

# %% [markdown]
# ### Limitations
# - No specific criteria was found for getting the Arousal and Intellect song characterstics, for this project we will be using Energy and Loudness? for getting the Arousal feature, and for Intellect, we will be using the Flesch Kincaid Reading Grade.
#
# - since we are relying on the tags from the Million Songs Database to filter out pop and country songs, we can potentially have a 'noisy' data, since we could have rock songs, or songs with other genres which were added with incorrect tags.  But we should be able to see all these when we try to create clusters for our songs.

# %% [markdown]
# ### Acquiring Data Set:
#
# Data sets were acquired from the different Sources:
#
# (1) To get the list of Artists, Songs, and genre tags records were extracted from the Million Song Database
#
# https://labrosa.ee.columbia.edu/millionsong/
#
# (2) To get audio features of the songs, Spotify API was used, given
# the artist name, and song title, the spotify Track ID can be retrieved, which can then be used to query the audio features for the song.
# <br><br>Spotify audio features are:
# - acousticness
# - danceability
# - duration_ms
# - energy
# - instrumentalness
# - key
# - liveness
# - loudness
# - mode
# - speechiness
# - tempo
# - time signature
# - valence
#
# (3) To get the lyrics of the songs, the Genius API will be used, to search the song based on a given Artist Name, and song title.
#
#
# the following notebooks will show the processing for each of these data acquisition steps:
# getArtistSong.ipynb:  get Artist/Songs from Million Song Database
# getFeatures.ipynb:    get Audio features via Spotify API
# getLyrics.ipynb:      get Song Lyrics via Genius API
#
# and were based on the following Open Source codes:
#
#
# ### Cleaning The Data
#
# 1) Combine the song data collected from Spotify with the Spotify Features, and the Lyrics collected from Genius.
#    Only keep records which both Spotify Features, and Lyrics Text from Genius.
#
#
# 2) The Spotify Features extracted were in JSON format.  Reformatted records to create a column for every Spotify Feature attribute.
#
# 3) Added a column 'genre' which was derived based on the tags found from the Song record.  A song was classified as 'pop' if 'pop' occurred in the tag the most, 'country' if 'country' occurred in the tag the most, otherwise, it will be tagged as 'other'.  This column will only be used for verifying output, but cannot provide a good score of accuracy since songs can be mis-tagged.  i.e. Beyonce's song records are tagged with 'country' instead of 'pop'.
#
# 4) Lyrics Text were cleaned to remove tags, i.e. [Verses], [Chorus].

# %%
import pandas as pd
import operator

# %%
def getGenre(df):
    """ This function reads and counts through the tags of a song record, and sets the genre with the type - pop, country
        or other that has the most counts, and returns a dataframe with new features added:
        genre: country, pop or other
        country_count: number of tags with 'country'
        pop_count: number of tags with 'pop'
        other_count: number of tags other than country or pop """
    
    for i, row in enumerate(df.itertuples(), start=0):
     
        rlist = []
        rtagcount = {'country': 0, 'pop': 0, 'other':0}
        
        if len(row.tags) > 0:
            for tag in row.tags:
            
                str1 = tag[0].strip().lower()    
            
                #count the number of occurrences of the word 'country' or 'pop' in tags
                if (str1.find('pop')) != -1:  #string contains pop
                    rtagcount['pop'] += 1
                elif (str1.find('country')) != -1:  #string contains country
                    rtagcount['country'] += 1
                else:
                    rtagcount['other'] += 1
    
    
                rlist.append(str1)  #set tag list with cleaned-up tags

        #set new column features with 'genre', 'genre_list', 'genre_count'
    
        df.set_value(i,'genre', max(rtagcount, key=lambda key: rtagcount[key]))
        df.set_value(i,'country_count', rtagcount['country'])
        df.set_value(i,'pop_count', rtagcount['pop'])
        df.set_value(i,'other_count', rtagcount['other'])
    
    return df

# %% [markdown]
# #### Gather and combine song Features and Lyrics Files extracted.

# %%
#Read the file with Spotify Features
pop_Features_A = pd.read_pickle('../data/msongs/out/popFeatures_1106_0to20000.p')
pop_Features_B = pd.read_pickle('../data/msongs/out/popFeatures_1107_20to40000.p')
#Read the file with Genius Lyrics
pop_Lyrics_A = pd.read_pickle('../data/msongs/out/DFPopLyrics_110618_0to20000.p')
pop_Lyrics_B = pd.read_pickle('../data/msongs/out/DFPopLyrics_110718_20to40000.p')

# %%
popF_A = pop_Features_A[0:20000].copy()
popF_B = pop_Features_B[20000:40000].copy()

popL_A = pop_Lyrics_A[0:20000].copy()
popL_B = pop_Lyrics_B[20000:40000].copy()

# %%
# empty dataframe to contain the subset
popF_DF = pd.DataFrame(data=None, columns=popF_A.columns)
popF_DF = popF_DF.append(popF_A, ignore_index=True)
popF_DF = popF_DF.append(popF_B, ignore_index=True)

# %%
# empty dataframe to contain the subset
popL_DF = pd.DataFrame(data=None, columns=popL_A.columns)
popL_DF = popL_DF.append(popL_A, ignore_index=True)
popL_DF = popL_DF.append(popL_B, ignore_index=True)

# %%
null_Lyrics_idx = popL_DF.index[popL_DF['lyrics_text'].isnull()]
popL_DF.drop(null_Lyrics_idx, inplace=True)

null_Features_idx = popF_DF.index[popF_DF['songFeatures'].isnull()]
popF_DF.drop(null_Features_idx, inplace=True)

# %% [markdown]
# #### Combine records where song is in both the Lyrics File and the Features File

# %%
pop_DF = popL_DF.merge(popF_DF, on=['artist_id','track_id', 'song_id'], how='inner').reset_index()

# %%
pop_DF.columns
# Out:
# Index(['index', 'index_x', 'artist_id', 'tags_x', 'track_id', 'title_x',
#        'song_id', 'release_x', 'artist_mbid_x', 'artist_name_x', 'duration_x',
#        'artist_familiarity_x', 'artist_hotttnesss_x', 'year_x',
#        'track_7digitalid_x', 'shs_perf_x', 'shs_work_x', 'lyrics_text',
#        'index_y', 'tags_y', 'title_y', 'release_y', 'artist_mbid_y',
#        'artist_name_y', 'duration_y', 'artist_familiarity_y',
#        'artist_hotttnesss_y', 'year_y', 'track_7digitalid_y', 'shs_perf_y',
#        'shs_work_y', 'spotifyURI', 'songFeatures'],
#       dtype='object')

# %%
#### add features
#### clean column id names to remove _x

# %% [markdown]
# #### Format Spotify Features and add columns to the Pop DataFrame

# %%
for i, row in enumerate(pop_DF.itertuples(),start=0):
   # print(row.artist_name_x, row.title_y, row.songFeatures)
    features = row.songFeatures[0]
    
    #save features as individual column names
    try:
        for key, value in features.items():
            pop_DF.set_value(i, key, value)
    except:
        print('error processing features for row {}'.format(i))
        #print(row.artist_name_x, row.title_y)
        #print(key, values)
# Out:
# error processing features for row 10557

# %%
none_Features_idx = pop_DF.index[pop_DF['valence'].isnull()]
pop_DF.drop(none_Features_idx, inplace=True)

# %%
pop_DF = pop_DF[['index', 'artist_id', 'tags_x', 'track_id', 'title_x',
       'song_id', 'release_x', 'artist_mbid_x', 'artist_name_x', 'duration_x',
       'artist_familiarity_x', 'artist_hotttnesss_x', 'year_x',
       'track_7digitalid_x', 'shs_perf_x', 'shs_work_x', 'lyrics_text','spotifyURI', 'songFeatures', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
       'track_href', 'analysis_url', 'duration_ms', 'time_signature']].copy()

# %%
# Rename columns to remove _x
for i in range(0,len(pop_DF.columns.values)):
    
    if (pop_DF.columns.values[i][-2] == '_') & (pop_DF.columns.values[i][-1] == 'x'):
        collen = len(pop_DF.columns.values[i])
        colstr = pop_DF.columns.values[i][0:(collen-2)]
        pop_DF.columns.values[i] = colstr

# %%
pop_DF.columns
# Out:
# Index(['index', 'artist_id', 'tags', 'track_id', 'title', 'song_id', 'release',
#        'artist_mbid', 'artist_name', 'duration', 'artist_familiarity',
#        'artist_hotttnesss', 'year', 'track_7digitalid', 'shs_perf', 'shs_work',
#        'lyrics_text', 'spotifyURI', 'songFeatures', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
pop_DF = getGenre(pop_DF)

# %%
pop_DF.columns
# Out:
# Index(['index', 'artist_id', 'tags', 'track_id', 'title', 'song_id', 'release',
#        'artist_mbid', 'artist_name', 'duration', 'artist_familiarity',
#        'artist_hotttnesss', 'year', 'track_7digitalid', 'shs_perf', 'shs_work',
#        'lyrics_text', 'spotifyURI', 'songFeatures', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature', 'genre',
#        'country_count', 'pop_count', 'other_count'],
#       dtype='object')

# %%
pop_DF.head()
# Out:
#    index           artist_id  \
# 0    0.0  AR009211187B989185
# 1    1.0  AR00FOZ1187FB5C9F3
# 2    2.0  AR00FOZ1187FB5C9F3
# 3    3.0  AR00FOZ1187FB5C9F3
# 4    4.0  AR00FOZ1187FB5C9F3
#
#                                                 tags            track_id  \
# 0  [(pop rock,), (pop,), (synthpop,), (reggae pop,)]  TRDBNUI128F933DE6E
# 1                [(synthpop,), (pop,), (pukkelpop,)]  TRWTSUW12903CD2DEA
# 2                [(synthpop,), (pop,), (pukkelpop,)]  TRNZCDV128F92F00A1
# 3                [(synthpop,), (pop,), (pukkelpop,)]  TRPGUDC12903CD2DEC
# 4                [(synthpop,), (pop,), (pukkelpop,)]  TRTMPTG128F92F00A0
#
#            title             song_id  \
# 0   I'm So Sorry  SOZCBYK12AB0180B4D
# 1  Stay The Same  SOBGFYV12AB018DEAD
# 2  Stay The Same  SOYUZXU12A58A78201
# 3  Stay The Same  SOBZAGY12AB018E2A5
# 4    Always More  SOUQQXB12A8C140687
#
#                                              release  \
# 0  The Best Of Original British Lovers Rock Volum...
# 1                                      Stay The Same
# 2                                             Animal
# 3                                      Stay The Same
# 4                                             Animal
#
#                             artist_mbid       artist_name   duration  \
# 0  9dfe78a6-6d91-454e-9b95-9d7722cbc476  Carroll Thompson  260.91057
# 1  92337972-f0c5-4ebd-be8c-f6b23d596ae1         autoKratz  404.97587
# 2  92337972-f0c5-4ebd-be8c-f6b23d596ae1         autoKratz  311.06567
# 3  92337972-f0c5-4ebd-be8c-f6b23d596ae1         autoKratz  277.73342
# 4  92337972-f0c5-4ebd-be8c-f6b23d596ae1         autoKratz  255.26812
#
#       ...                           id                                   uri  \
# 0     ...       19mWMfe0fX4lm3V4fXkyA6  spotify:track:19mWMfe0fX4lm3V4fXkyA6
# 1     ...       1wZY4LPJsABndQeoqzsyOX  spotify:track:1wZY4LPJsABndQeoqzsyOX
# 2     ...       1gZ4TP1pQwRD5WhYKDG0jw  spotify:track:1gZ4TP1pQwRD5WhYKDG0jw
# 3     ...       26wPSNT05P58sCin1svhtd  spotify:track:26wPSNT05P58sCin1svhtd
# 4     ...       1gZ4TP1pQwRD5WhYKDG0jw  spotify:track:1gZ4TP1pQwRD5WhYKDG0jw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/19mWMfe0fX4l...
# 1  https://api.spotify.com/v1/tracks/1wZY4LPJsABn...
# 2  https://api.spotify.com/v1/tracks/1gZ4TP1pQwRD...
# 3  https://api.spotify.com/v1/tracks/26wPSNT05P58...
# 4  https://api.spotify.com/v1/tracks/1gZ4TP1pQwRD...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/19mW...    426520.0
# 1  https://api.spotify.com/v1/audio-analysis/1wZY...    283333.0
# 2  https://api.spotify.com/v1/audio-analysis/1gZ4...    311200.0
# 3  https://api.spotify.com/v1/audio-analysis/26wP...    291000.0
# 4  https://api.spotify.com/v1/audio-analysis/1gZ4...    311200.0
#
#   time_signature genre country_count pop_count  other_count
# 0            4.0   pop           0.0       4.0          0.0
# 1            4.0   pop           0.0       3.0          0.0
# 2            4.0   pop           0.0       3.0          0.0
# 3            4.0   pop           0.0       3.0          0.0
# 4            4.0   pop           0.0       3.0          0.0
#
# [5 rows x 41 columns]

# %%
### Save pre-processed Pop File

pop_DF.to_pickle('../data/msongs/out/Pop_Preprocessed_1109')

# %% [markdown]
# #### Process other batches of files

# %%
### Process Country features and Lyrics Files

# %%
#Read the file with Spotify Features
country_Features = pd.read_pickle('countryFeatures.p')

# %%
#Read the file with Genius Lyrics
country_Lyrics = pd.read_pickle('countryLyrics_1105.p')

# %%
null_Lyrics_idx = country_Lyrics.index[country_Lyrics['lyrics_text'].isnull()]
country_Lyrics.drop(null_Lyrics_idx, inplace=True)

# %%
len(country_Lyrics)
# Out:
# 27579

# %%
null_Features_idx = country_Features.index[country_Features['songFeatures'].isnull()]
country_Features.drop(null_Features_idx, inplace=True)

# %%
len(country_Features)
# Out:
# 23312

# %%
country_DF = country_Lyrics.merge(country_Features, on=['artist_id','track_id', 'song_id'], how='inner')

# %%
len(country_DF)
# Out:
# 13006

# %%
country_DF.columns
# Out:
# Index(['index_x', 'artist_id', 'tags_x', 'track_id', 'title_x', 'song_id',
#        'release_x', 'artist_mbid_x', 'artist_name_x', 'duration_x',
#        'artist_familiarity_x', 'artist_hotttnesss_x', 'year_x',
#        'track_7digitalid_x', 'shs_perf_x', 'shs_work_x', 'lyrics_text',
#        'index_y', 'tags_y', 'title_y', 'release_y', 'artist_mbid_y',
#        'artist_name_y', 'duration_y', 'artist_familiarity_y',
#        'artist_hotttnesss_y', 'year_y', 'track_7digitalid_y', 'shs_perf_y',
#        'shs_work_y', 'spotifyURI', 'songFeatures'],
#       dtype='object')

# %% [markdown]
# - format features to create new columns - done
# - create new features, i.e. intelligence, emotions
# - run clustering against features
# - look for patterns
# - run PCA
# - set labels
# - get NLP features for lyric processing
# - clean text data, filter for english songs only

# %%
#Reset index of DataFrame prior to processing
country_DF.reset_index(inplace=True)

# %%
country_DF.columns
# Out:
# Index(['index', 'index_x', 'artist_id', 'tags_x', 'track_id', 'title_x',
#        'song_id', 'release_x', 'artist_mbid_x', 'artist_name_x', 'duration_x',
#        'artist_familiarity_x', 'artist_hotttnesss_x', 'year_x',
#        'track_7digitalid_x', 'shs_perf_x', 'shs_work_x', 'lyrics_text',
#        'index_y', 'tags_y', 'title_y', 'release_y', 'artist_mbid_y',
#        'artist_name_y', 'duration_y', 'artist_familiarity_y',
#        'artist_hotttnesss_y', 'year_y', 'track_7digitalid_y', 'shs_perf_y',
#        'shs_work_y', 'spotifyURI', 'songFeatures'],
#       dtype='object')

# %% [markdown]
# #### Format songFeatures retrieved from Spotify to create new feature columns

# %%
for i, row in enumerate(country_DF.itertuples(),start=0):
   # print(row.artist_name_x, row.title_y, row.songFeatures)
    features = row.songFeatures[0]
    
    #save features as individual column names
    try:
        for key, value in features.items():
            country_DF.set_value(i, key, value)
    except:
        print('error processing features for row {}'.format(i))
        #print(row.artist_name_x, row.title_y)
        #print(key, values)
# Out:
# error processing features for row 772
# error processing features for row 773
# error processing features for row 774
# error processing features for row 775
# error processing features for row 776
# error processing features for row 777
# error processing features for row 778
# error processing features for row 779
# error processing features for row 780
# error processing features for row 781
# error processing features for row 782
# error processing features for row 783
# error processing features for row 784
# error processing features for row 785
# error processing features for row 786
# error processing features for row 787
# error processing features for row 788
# error processing features for row 789
# error processing features for row 790
# error processing features for row 791
# error processing features for row 792
# error processing features for row 794
# error processing features for row 795
# error processing features for row 796
# error processing features for row 797
# error processing features for row 798
# error processing features for row 799
# error processing features for row 800
# error processing features for row 801
# error processing features for row 2740
# error processing features for row 2741
# error processing features for row 2744
# error processing features for row 2745
# error processing features for row 2746

# %%
none_Features_idx = country_DF.index[country_DF['valence'].isnull()]
country_DF.drop(none_Features_idx, inplace=True)

# %%
dfCountry = country_DF[['index', 'artist_id', 'tags_x', 'track_id', 'title_x',
       'song_id', 'release_x', 'artist_mbid_x', 'artist_name_x', 'duration_x',
       'artist_familiarity_x', 'artist_hotttnesss_x', 'year_x',
       'track_7digitalid_x', 'shs_perf_x', 'shs_work_x', 'lyrics_text','spotifyURI', 'songFeatures', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
       'track_href', 'analysis_url', 'duration_ms', 'time_signature']].copy()

# %%
# Rename columns to remove _x
for i in range(0,len(dfCountry.columns.values)):
    
    if (dfCountry.columns.values[i][-2] == '_') & (dfCountry.columns.values[i][-1] == 'x'):
        collen = len(dfCountry.columns.values[i])
        colstr = dfCountry.columns.values[i][0:(collen-2)]
        dfCountry.columns.values[i] = colstr

# %%
dfCountry.columns
# Out:
# Index(['index', 'artist_id', 'tags', 'track_id', 'title', 'song_id', 'release',
#        'artist_mbid', 'artist_name', 'duration', 'artist_familiarity',
#        'artist_hotttnesss', 'year', 'track_7digitalid', 'shs_perf', 'shs_work',
#        'lyrics_text', 'spotifyURI', 'songFeatures', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(dfCountry[dfCountry.year > 2005][['artist_id','artist_name']].drop_duplicates().sort_values(by='artist_name'))
# Out:
#                 artist_id                          artist_name
# 124    AR08IOK1187FB5B78E                           A.A. Bondy
# 9125   ARCN61O1187B9ABBE8                        Aaron Neville
# 8619   ARBZHTB1187FB3A725                         Aaron Watson
# 70     AR02T3I1187FB4D0E5                            Aberfeldy
# 5357   AR7DO6G1187FB41056                           Adam Faith
# 3988   AR60LUY1187B98C8CD                           Afterhours
# 10032  ARDUFS01187FB4CF5E                          Against Me!
# 1467   AR2BS1V1187B9AA66D                         Akron/Family
# 5676   AR80BY41187B98DECF                          Albert King
# 3234   AR4TJDF1187FB59D3D                           Albert Pla
# 8419   ARBOBNN1187B98E706                           Aled Jones
# 12712  ARGMKGE1187FB44E41                         Alesha Dixon
# 550    AR0TZ1F1187FB4AD1E                      Alexandre Pires
# 1022   AR1PYXY1187FB42576                        Alexi Murdoch
# 10230  ARE2XN81187B98BB83                            Alexis HK
# 11772  ARFMT4W1187FB42FA8                        Alison Krauss
# 2348   AR3NOZW1187FB4CF9C                         Alpha Blondy
# 2673   AR3ZFPV1187FB368C7                       Alvin Stardust
# 8109   ARB9TN21187FB568DA                           Amparanoia
# 10104  ARDXJ0E1187FB44B0A                      Andrew Peterson
# 2012   AR38A0J1187FB39BE8                           Ann Wilson
# 5126   AR75SGJ1187B9B80DA                     Anthony Hamilton
# 10612  AREHM5A1187FB3DE00                   Antonello Venditti
# 10828  AREQTHU1187FB4D4D7                               Argent
# 3698   AR5IRF11187FB5494B                        Art In Manila
# 12603  ARGJ8UQ1187B996656                      Ashley MacIsaac
# 8092   ARB8H82119B34032E1                      Ashton Shepherd
# 6056   AR8KJG41187B9AF8EC                     Assembly of Dust
# 12938  ARH5CVB1187FB5A1B3               Atlanta Rhythm Section
# 1975   AR3518X1187B98C415                          Automatic 7
# 9841   ARDKMQZ1187B9A8803                         Axe Riverboy
# 2944   AR4GAFY1187B9B639D                            B.B. King
# 1856   AR2ZCJ51187B9A5EC8                                  B2K
# 2284   AR3JMC51187B9AE49D                      Backstreet Boys
# 11900  ARFTQS41187FB4D96C                        Bad Astronaut
# 8024   ARB3YN21187FB4FA2F                              Ballboy
# 284    AR0L55W1187B9B46FA                      Barbara Dickson
# 1934   AR32P6E1187FB36096                        Bargain Music
# 8897   ARCENE01187B9AF929                          Barleyjuice
# 6273   AR8WV031187FB3F903                           Basshunter
# 12101  ARFYR4G11C8A41490F                        Beats Antique
# 2508   AR3USQW1187FB4A90D                          Bebo Norman
# 8719   ARC2XR11187FB5CC95                                 Beck
# 4584   AR6LKUT1187FB57287                             Bee Gees
# 10466  AREBWEH1187B99EA9A                              Beherit
# 6071   AR8KM711187B98CD0D                           Belleruche
# 7533   ARAKR2K1187B9AA5AB                           Bellowhead
# 5174   AR76NY61187FB4F82F                            Ben Folds
# 4574   AR6KICS1187FB46664                        Ben Westbeech
# 2570   AR3VUBA1187FB511AC                        Ben's Brother
# 2483   AR3TYNR1187FB3A365                         Benjy Ferree
# 8758   ARC5GDC1187FB5B155                      Bernard Allison
# 2842   AR47N9A1187B988BF4                          Beth Rowley
# 6474   AR94SFV1187FB4DA2C                     Better Than Ezra
# 7100   AR9TCXZ1187FB4D9E8                      Bettie Serveert
# 4083   AR65K7A1187FB4DAA4                              Beyoncé
# 6267   AR8VURH1187B9B4585                             Bill Fay
# 940    AR1IA5V1187B98AF6E              Bill Haley & His Comets
# 4753   AR6QRP91187B98F5AF                           Bill Wyman
# 5623   AR7XWWT1187B9A68DA                   Billy Bob Thornton
# 2878   AR49F631187B98BFA6                     Billy Boy Arnold
# 2902   AR4DW2Q1187FB44DB6                     Billy Currington
# 6097   AR8LPN61187FB5953A                       Bitman & Roban
# 8427   ARBQ2MC1187B9A6C20                        Bjørn Eidsvåg
# 8132   ARB9VOK119B86685D0                             Blaudzun
# 5875   AR8BBST1187B9979E1                       Blind Guardian
# 10242  ARE36MM1187B991E50                Blind Lemon Jefferson
# 11816  ARFNTQD12086C1240E                           Blue Giant
# 7570   ARANU621187B98C81B                         Blue Highway
# 9471   ARD842G1187B997376                           Blue Rodeo
# 11267  ARFB30B1187FB42AB9                       Blues Traveler
# 3668   AR5FP401187FB523C9                            Bob Dylan
# 5685   AR81NA61187FB4046A                            Bob Mould
# 841    AR19SOA1187B98F6E6                         Bob Neuwirth
# 9288   ARD0FN11187B9B25CD                          Bobby Darin
# 839    AR199SO1187FB5B96C                   Bobby Lee Trammell
# 11467  ARFFCVK1187FB40EAA                      Bodies Of Water
# 12783  ARGR5JB1187B9B5D15                 Bombay Dub Orchestra
# 3752   AR5MKYH1187B9B586D                         Bonnie Tyler
# 2761   AR43IDV1187FB4691A                        Born Ruffians
# 8407   ARBMZKY1187B98FCE9                   Botellita De Jerez
# 6272   AR8W4KE1187FB59C7B                   Boudewijn de Groot
# 1240   AR1XZGQ1187FB45CD0                           Bowerbirds
# 3524   AR58OF61187FB3D566                          Brave Combo
# 12628  ARGKD4W1187B990E04                           Brenda Lee
# 9529   ARD9UVF1187B9B17FE                         Brian Wilson
# 7506   ARAGY6J1187FB40B17            Brightblack Morning Light
# 11001  AREZWXB1187FB4958E                        Brooks & Dunn
# 3697   AR5IPD21187FB5CCC6                        Bruce Channel
# 6366   AR91C8S1187B990901                    Bruce Springsteen
# 9411   ARD6NTO1187B994ED1                   Buffy Sainte-Marie
# 7001   AR9Q34X1187B9A28B6                       Caedmon's Call
# 5957   AR8GYV21187B9ABE91                       Caetano Veloso
# 7527   ARAIIMT11F4C83D2C7                             Callisto
# 6445   AR93ZCZ1187FB4409A                          Cara Dillon
# 11714  ARFMHB31187FB47644                          Carbon Leaf
# 7881   ARB1KC91187FB38B13                           Carl Smith
# 2402   AR3PF2S1187FB389E3                       Carlene Carter
# 11215  ARFAN5B1187FB3A6BB                          Carly Simon
# 9395   ARD4JC41187FB3DF65                       Carter Burwell
# 7466   ARAFPO71187B9BA100                     Cassandra Wilson
# 12775  ARGOOFV1241B9C54EA                          Cast Spells
# 6404   AR91NIO1187FB4D732                            Cat Power
# 2133   AR3EZNY1187B9B7CED                  Cattle Decapitation
# 2186   AR3FDXK1187FB3BDAD                         Centro-matic
# 9620   ARDAV6Z1187FB5A1D6                       Charley Jordan
# 7374   ARA82JG1187FB36131                        Charlie Haden
# 8697   ARC23S41187B9A920E                  Charlie Musselwhite
# 3378   AR5278F1187B9A25C8                      Charlie Robison
# 1174   AR1WD3J1187FB45A30                   Charlotte Perrelli
# 5771   AR83W3J1187B9A980E                  Chatham County Line
# 3764   AR5NYWW1187B993C1A                       Chavela Vargas
# 10654  AREMEW61187B9B62DD                          Cheap Trick
# 5302   AR7C9271187FB39BF8                         Chely Wright
# 9713   ARDBTUA1187B989FAC                       Chico Trujillo
# 11586  ARFL8LM1187B989D0D                          Chris Cagle
# 9849   ARDL7S81187FB37625                        Chris Cornell
# 1284   AR207Y01187B98E9E6                         Chris Knight
# 1528   AR2CD9Z1187FB5B754                          Chris Thile
# 10831  ARER3QP1187B9A8DC4                         Chris Tomlin
# 7679   ARARUSD1187B9A5050                     Christer Sjögren
# 2616   AR3Z3U71187FB36BD1                    Christine Fellows
# 1535   AR2D7TS1187FB560F1                           Chromatics
# 4588   AR6NBDC1187FB4D96D                          Chuck Berry
# 98     AR05QTW1187B9913F9                         Chuck Willis
# 8044   ARB42181187B9A4656              Circle Of Dead Children
# 3856   AR5PCKC1187B98A965                        Cisco Houston
# 9140   ARCP8YG1187B997D72                        Claire Hamill
# 8524   ARBU6D71187B9B5319           Clarence "Gatemouth" Brown
# 4420   AR6EVQA1187B9AA1DF                            Cocoa Tea
# 4606   AR6OL631187FB49241                        Colby O'Donis
# 8083   ARB7BE11187B9B64E9                      Colin Blunstone
# 630    AR0Y7ET1187FB5763C                          Colin Meloy
# 9094   ARCMJPV123526A05FE                            Colt Ford
# 12766  ARGONW711C8A415AB6                         Conor Oberst
# 11173  ARFA1IP1187FB4BF33                         Constantines
# 6345   AR90TFQ1187FB4E9A6                      Cortney Tidwell
# 8188   ARBEU5F1187B99C3FE                          Cory Branan
# 7464   ARAFMN71187FB52EFD                          Cory Morrow
# 5427   AR7I73V1187B9AF8A9                Count Basie Orchestra
# 7768   ARAXTRL1187FB3F424                        Crooked Still
# 12051  ARFWL8S1187B9B4B44                          Céline Dion
# 8311   ARBIVRF1187FB3F570                          Dale Watson
# 8182   ARBERTC1187B9ABD80                               Dalida
# 4759   AR6T2Z31187B9B437D                        Damien Jurado
# 3423   AR53RLV1187FB39AA5                               Damone
# 12889  ARH0AWA1187B9AB7F0                         Dan Auerbach
# 12883  ARH04B41187FB59158                        Dan Fogelberg
# 3018   AR4JL9A1187B98C936                          Dan Sartain
# 2388   AR3OWHF1187FB5B75D                         Dan Tyminski
# 7651   ARARUDU1187B9A87C7                        Daniël Lohues
# 6812   AR9LT7R1187FB4543A                         Darden Smith
# 2104   AR3ETJY1187B98ED15                        Darius Rucker
# 3868   AR5TZGY1187FB3FFDB                       Darker My Love
# 12313  ARGBHWR11F50C4A09B                         Darla Farmer
# 9259   ARCZD9J1187FB3BC5B                        Darren Hanlon
# 3796   AR5OB9M1187FB52F29                        Darryl Worley
# 12804  ARGUNFT1187FB3B140                           Dave Alvin
# 2981   AR4II141187B9A7B7E                          Dave Barnes
# 12116  ARFZSCK1187FB5291A                         Dave Cousins
# 7580   ARAOAKL1187FB4F2FD                         Dave Edmunds
# 3258   AR4TPZ21187FB4C5CB                        David Cassidy
# 11798  ARFN2TE11A348EFFB4                           David Cook
# 3014   AR4IXBW1187FB3DE3F                        David Dondero
# 1768   AR2W4T81187FB410A7                        David Gilmour
# 3114   AR4Q9XI1187FB40210                           David Mead
# 3311   AR4WP491187B9A9139                          Dawn Landes
# 11666  ARFM0TP1187B9A0745                        Delta Goodrem
# 1405   AR23YR81187FB5814F                         Delta Spirit
# 5836   AR8AYDW1187FB4BA8F                       Denison Witmer
# 5823   AR8AQT211C8A42113F                             Deolinda
# 7622   ARAQSGR11E2835CE97                            Deportees
# 4073   AR64S5V1187B9A8DC6                               Devics
# 1582   AR2K3Q81187B9B44A2                        Devon Sproule
# 12090  ARFX19311C8A422AE0                        Diamond Rings
# 1664   AR2SG8E1187FB52CDD                          Diamond Rio
# 2190   AR3FYKL1187FB44945                       Dierks Bentley
# 687    AR11YQ81187FB3C654                         Dixie Chicks
# 737    AR14H7M1187FB4716C                    Do Make Say Think
# 1114   AR1T75N1187B99A372                             Dolorean
# 12942  ARH5Y3F1187FB4A177                         Don Williams
# 3898   AR5VBN51187FB56E51                      Dorsey Burnette
# 10821  AREQRHG1187FB4D2B5                          Dot Allison
# 2236   AR3GVU31187B98B00E                                Dozer
# 213    AR0H0IB1187B9A3780                        Dr Rubberfunk
# 2810   AR45KNL1187B992E53                             Dr. Elmo
# 1698   AR2TPGH1187FB435C1                          Drew Sidora
# 9296   ARD2NDU1187B99B615                     Dropkick Murphys
# 7563   ARANS3K1187B9B4FEA                       Dustin Kensrue
# 10814  AREQIT21187B9AEB7F                    Dusty Springfield
# 4671   AR6P06Z1187FB3C1E8                            Earlimart
# 12191  ARG3CPP1187B99C82A                         Earth Crisis
# 6863   AR9O6V81187FB3E38B                          Ed Harcourt
# 1879   AR2ZNXL1187B9B87A1                          Eddi Reader
# 9027   ARCK9VW1187B98C066                           Edo Maajka
# 9046   ARCKRZZ1187B9A2E71                              El Caco
# 9783   ARDERJ41187B999AB8                   Electric President
# 1238   AR1XRGZ1187FB5392A                           Ellis Paul
# 8841   ARC7ZMH1187FB3701D                    Elvira Nikolaisen
# 6234   AR8RSG31187FB4AA4F                        Elvis Perkins
# 5741   AR83QRD1187FB5BF49                        Emerson Drive
# 7153   AR9VCSR1187B9B879E                       Emmylou Harris
# 4999   AR714KG1187FB58FCB                Engelbert Humperdinck
# 5010   AR71XBM1187B9AF07B                        Enzo Jannacci
# 5918   AR8EZZK1187FB4F6C2                             Erdmöbel
# 7969   ARB3BJV1187FB4C3D6                        Erik Og Kriss
# 1424   AR24DZB1187FB3C869                          Erykah Badu
# 3069   AR4M2AL1187B9B828B                               Espers
# 9200   ARCWE091187FB4A539                           Essie Jain
# 6341   AR90C7F1187FB3EEED                     Estrella Morente
# 11831  ARFQQBZ119B86688C1                          Evangelista
# 4401   AR6DYWJ1187B9AF8A5                        Ewan McGregor
# 7376   ARA8MJT1187FB5C48A                                Faker
# 11495  ARFG2HF1187FB3D4EC                               Feeder
# 4602   AR6NRQI1187FB37544                                Feist
# 10204  ARE0WE31187FB48835                        Findlay Brown
# 4279   AR6BNBY1187B998232                        Finger Eleven
# 200    AR0EJXK1187FB4E27D                      Florent Marchet
# 9173   ARCVKG01187B9B3273                              Flyleaf
# 4910   AR6XPWV1187B9ADAEB                         Foo Fighters
# 11337  ARFCJOM12472CE2AEE                        Former Ghosts
# 9673   ARDBSFT1187B9AC9C1                   Fountains Of Wayne
# 5109   AR75G5G1187B9B6758                          Frank Reyes
# 12848  ARGYVSP1187FB445BC                       Frankie Avalon
# 10796  AREPU3F1187FB4E9CC                                Frida
# 2231   AR3GMEL1187B9B2BB9                         Gabriel Rios
# 8401   ARBLOKB122BCFCC8D7                            Ganglians
# 6666   AR9G9BT1187B995F86                       Garrison Starr
# 3454   AR56P361187B9AC4DB                           Gary Moore
# 10906  AREVXAC1187B998BED                      Gatas Parlament
# 3223   AR4SOKG1187B98D2B0                      Geier Sturzflug
# 11530  ARFJ3CE1187B99612E                          Gemma Hayes
# 10387  ARE7OYH1187B99F5AB                        Gentleman Reg
# 5679   AR81C931187B9A7747                        Georgia Gibbs
# 12574  ARGI63K1187FB42D76             Get Cape. Wear Cape. Fly
# 7753   ARAWK7J1187FB3D8C5                        Ghost Buffalo
# 134    AR09RBO1187FB3C236                           Giant Sand
# 10948  AREYJKQ1187B9AEAB5                         Gin Blossoms
# 1944   AR33KSV1187FB4B900             Gladys Knight & The Pips
# 5961   AR8H87D1187FB3A841                        Glen Campbell
# 1138   AR1TIS71187FB37160                       Gloria Estefan
# 5993   AR8ICRA1187B9B8A5F                             Godsmack
# 12304  ARG8NEM1187B99A0B5                               Goloka
# 11213  ARFAC0T1187B98C410                          Graham Nash
# 7595   ARAPIIU1187B98FAC9                         Gram Parsons
# 8237   ARBG45N1187FB38F2E                           Grant Hart
# 10745  AREP0H61187FB443CF                        Grayson Capps
# 12342  ARGBZ8J1187B9AA40C                        Great Big Sea
# 6570   AR98J891187B99C3B6                  Great Lake Swimmers
# 7932   ARB33IT1187FB4ED69                        Griffin House
# 11300  ARFBTBY1187FB517BF                          Groundation
# 761    AR1587M1187B9A4E88                           Gruff Rhys
# 5499   AR7PY5D1187FB5B2FB                            Guy Clark
# 100    AR06VF41187B9B2BCB                Half Man Half Biscuit
# 621    AR0X3JJ1187FB3A9A7                         Hank Locklin
# 1573   AR2GWFK1187FB38CBF                            Hank Snow
# 4750   AR6QCJA1187FB56BE8                        Hank Thompson
# 9142   ARCPGUK1187B988D09                               Hannah
# 7704   ARAUA5K1187B9AA95F                     Hanne Hukkelberg
# 11511  ARFGXKD1187B99C341                       Hans Theessink
# 5778   AR86J6P1187B9B66FD                         Harry Chapin
# 12346  ARGCVZG1187B9B916F                        Hayseed Dixie
# 4301   AR6BW1L1187B9B7995                   Heartless Bastards
# 12899  ARH0LQY1187FB5AC64                          Heavy Trash
# 12678  ARGLU5L1187FB57EC5                          Hellbillies
# 8768   ARC6UC81187B989062                                  Hem
# 2945   AR4GR7S1187FB3734A                       Heroes & Zeros
# 9578   ARDAHWH1187FB4B0E7                           Hoobastank
# 7348   ARA6O2O1187B997189                        Hugh Cornwell
# 5073   AR74ORG1187B9AE93D                      Hundred Reasons
# 9211   ARCXFK31187FB35FC1                          Hush Arbors
# 1440   AR258TI11C8A416B5B             I Set My Friends On Fire
# 1787   AR2WOOQ1187B98E303                             Idlewild
# 10450  AREB12I11C8A416B50                           Imelda May
# 1089   AR1RPHQ1187B9B8D6D                     In-Flight Safety
# 6433   AR93D4D1187FB3ACAD                            J.J. Cale
# 8542   ARBUBTM122E6447DC4                                  JLS
# 12550  ARGHYWC1187B9B06E4                            Jake Owen
# 10325  ARE4XV51187B9AC51E                          Jakob Dylan
# 11935  ARFVCBZ1187FB4CBE7                       James McMurtry
# 9622   ARDB9J71187FB4AB8B                       James Yorkston
# 8630   ARBZX3K1187FB3F5FC                         Jamie O'Neal
# 429    AR0OWAU1187FB5B7E5                           Jamie Woon
# 3338   AR4XC211187B9B7F39                            Janis Ian
# 1170   AR1UPX11187FB54040                         Janis Martin
# 12966  ARH6BN71187B990C51                         Jason Aldean
# 7496   ARAGNTU1187B9B3227                          Jason Lytle
# 462    AR0QN8S1187B9B0DFB                         Jason Molina
# 12736  ARGNQJ51187B99D650                          Jeff Healey
# 4511   AR6GVSZ1187FB36FFB                        Jeffrey Lewis
# 9325   ARD2VKC1187FB57F38                     Jenni Vartiainen
# 7053   AR9QYWN1187B9B3E3F                      Jeremy Warmsley
# 10410  ARE7QFG1187FB42032                         Jesse Harris
# 10173  ARE0OLY1187B9AD19F                          Jesse Malin
# 10892  AREVQ0H1187B9A95FD    Jesse Sykes & The Sweet Hereafter
# 12707  ARGMAUZ1187B9940F1                         Jim O'Rourke
# 10624  AREIZH41187B9A108D                         Joan Osborne
# 3196   AR4RHX31187B9B7FA1                            Joe Henry
# 1466   AR2BFFA11C8A4211FB                            Joe Jonas
# 9054   ARCLPC51187FB52F2D                          Joe Nichols
# 6680   AR9GYK61187B9BA1DD                     John Butler Trio
# 290    AR0LFJ41187B9BA10E                         John Farnham
# 10137  ARDZQ5U1187B9ADEAE                         John Fogerty
# 9468   ARD80VO1187B991B4B                            John Foxx
# 3548   AR5AKHZ1187FB46B9F              John Michael Montgomery
# 8156   ARBDFT61187FB4C5E8                          John Waller
# 1259   AR1Y2PT1187FB5B9CE                          John Wesley
# 8396   ARBL2N51187B99ADBB                       Johnny Carroll
# 6302   AR8XIN91187FB3A048                        Johnny Mathis
# 8974   ARCI02G1187B98AA7A                      Johnny Paycheck
# 5606   AR7W8OQ1187FB5A9FC                        Jon Snodgrass
# 8253   ARBHBE91187B9A1F58                           Jonny Lang
# 7201   ARA04401187B991E6E                          Josef Locke
# 5337   AR7DFJP1187B992F13                         Juana Molina
# 7395   ARA90G21187FB454A4                       Julie Collings
# 11961  ARFVHX11187B999552                         Julie Feeney
# 8844   ARC87OG1187B99F540                        Julie Roberts
# 5846   AR8AZTM1187FB3FB9C                    Julio Iglesias Jr
# 11355  ARFCWSZ123526A0AFD                        Justin Bieber
# 5054   AR73V031187B9A1883                      Justine Electra
# 8981   ARCJKV91187FB46210                          KT Tunstall
# 5779   AR86PKD1187FB38EC7                         Kailash Kher
# 309    AR0N8D61187FB3D0D6                    Kaizers Orchestra
# 3469   AR56SB71187B9B8041                          Karen Elson
# 404    AR0O9GK11A348F08F6                    Karen Taylor-Good
# 4843   AR6W3ET1187B997DE7                         Kari Bremnes
# 9562   ARDABV91187B995B84                       Karine Polwart
# 4691   AR6P44B1187FB5B59B                           Kate Rusby
# 12128  ARG21NE1187B9A910E                           Kate Walsh
# 857    AR1DR0E1187FB48F61                         Kathy Mattea
# 2583   AR3WRJS1187B9B65ED                         Keisha White
# 6489   AR95IYB1187FB3FE0B                          Keith Urban
# 1384   AR23BO81187FB47087                       Kellie Pickler
# 5728   AR83G9J1187FB3C094                        Kenny Loggins
# 7876   ARB12S31187FB48948                           Kery James
# 10351  ARE5L8P1187B993531                       Kevin Johansen
# 3029   AR4JOEZ1187B9AE99A                             Kid Rock
# 3862   AR5R6781187B98BE78                          Killer Mike
# 5410   AR7I2SJ1187B9B41C3                           Kim Richey
# 8144   ARBAP9P1187FB5676A                        King Creosote
# 3218   AR4SEOV1187FB5476F                          Kris Drever
# 8433   ARBQPXY1187B98D67B                   Kris Kristofferson
# 11544  ARFJGR11187FB526F5                     Kristofer Åström
# 5021   AR72PJV1187B9A72CE                          Kultiration
# 998    AR1OAYQ1187B99F223                           Kumikameli
# 4853   AR6W9AC1187B9930F0                                 Kyte
# 4981   AR6XTOU1187FB585F1                        La Buena Vida
# 8935   ARCGWLH1187B9AC714                              LaBelle
# 11553  ARFJXKQ119B86694AF                      Lady Antebellum
# 9502   ARD91BF1187FB385D5                        Lalo Schifrin
# 4069   AR64GHS1187FB3C031                             Lambchop
# 7596   ARAPRJI1187B9ACEBD                       Laura Cantrell
# 7131   AR9U4HF1187FB50346                           Laura Nyro
# 10250  ARE3LP51187B9ACD29                          LeAnn Rimes
# 186    AR0BV7E1187FB386C1                         Lee Ritenour
# 11617  ARFL93Y1187B98FAC3                      Lee Roy Parnell
# 945    AR1L5HB119B340372E                    Left Lane Cruiser
# 6049   AR8JO2B1187B98EBB6                       Leftöver Crack
# 1559   AR2FJV21187B98EBE3                          Legacy Five
# 3049   AR4LKSS1187B9B2153                           Leigh Nash
# 11185  ARFA4301187B9AD04A                        Lenny Kravitz
# 6121   AR8MJ3N1187B98BF81                             Les Paul
# 6312   AR8XOFS1187FB3711C                         Les Savy Fav
# 5508   AR7QE9M1187B9B07C1                            Levellers
# 5428   AR7ICFK1187B9955FF                           Levon Helm
# 11141  ARF69MA1187FB3E9A0                         Lisa Gerrard
# 5390   AR7HABR1187FB3EC1B                        Lisa Hannigan
# 11058  ARF3FBD1187FB40B90                       Little Brother
# 7739   ARAWGDQ11FF10D8556                        Local Natives
# 12193  ARG4J2T1187FB3A8B8                         Lori McKenna
# 11543  ARFJD5L1187B9A30BA                          Los Van Van
# 2822   AR46A091187B99CA6C                          Lovespirals
# 7307   ARA4PAE1187FB551CC  Low Low Low La La La Love Love Love
# 10259  ARE3PRA1187FB39AB7                     Lucinda Williams
# 653    AR10B9G1187FB561CE                           Lucky Dube
# 1605   AR2PXBU1187FB5BB30                           Luka Bloom
# 12687  ARGM4PB1187FB3DEFB                            Luz Casal
# 3608   AR5DHN51187B9B9363                            Macy Gray
# 8496   ARBTWBU1187B9973C4                    Malcolm Middleton
# 3355   AR50LUJ1187B9ACA8B                            Manu Chao
# 965    AR1MKBJ1187B996272                            Marc Ford
# 5555   AR7SN7L1187FB39613                          Marc Moulin
# 8822   ARC7HL11187B99806E                          Maria McKee
# 8203   ARBF2LC1187B99F39E                      Maria de Barros
# 6657   AR9FKRD1187B9B73D4                   Marianne Faithfull
# 9210   ARCX85Z1187FB558D5                          Mario Lanza
# 10413  ARE9R6I1187B98EA09                        Mark Knopfler
# 4813   AR6URKE1187B9BA4D1                         Mark Kozelek
# 3556   AR5AQ6H1187B9B78B6                         Mark Mulcahy
# 3594   AR5CYNT1187FB4EDFF                         Marla Hansen
# 2457   AR3SA631187FB37336                          Marte Wulff
# 3244   AR4TLW81187B99683D                        Martin Sexton
# 11065  ARF3GX71187FB3EB66                      Martina McBride
# 1065   AR1QVPU1187FB56B47                        Mary Gauthier
# 1701   AR2U6Z81187B9A7BA6                          Mary Hopkin
# 12559  ARGI5FG1187B9A1A70                            Matt Dusk
# 12232  ARG5GH71187FB4C030                            Matt Mays
# 12816  ARGWNT41187FB463F1                         Matt Pond PA
# 3559   AR5BBK81187B990027                          Matt Redman
# 11322  ARFC7T81187B9A3292               Matthew Perryman Jones
# 12289  ARG87LT1187B9B09A1                        Matthew Sweet
# 11160  ARF9YM51187B99C1FD                         Matthew West
# 9232   ARCZ5JJ1187FB3E221                        Mavis Staples
# 528    AR0RW5L1187FB4E133                   Mccarthy Trenching
# 6053   AR8JZZ41187FB4FE0D                            Meg Baird
# 8398   ARBL7U51187FB3B56D                      Melissa Ferrick
# 6990   AR9OVHD1187B98A8BE                      Men Of Standard
# 3339   AR4XV7Y1187FB41004                          Mercan Dede
# 2835   AR470HW1187FB3B8DF                        Merle Haggard
# 3033   AR4JP7C1187FB4E758                     Message To Bears
# 7416   ARACQWA1187FB40C72                         Mia Doi Todd
# 3373   AR51JTF1187FB395B9                    Michelle Williams
# 543    AR0TAEM1187FB36C4B                   Middle Of The Road
# 12866  ARGZG0Z1187FB4B280                            Mike Batt
# 9015   ARCJQ9N1187B992EA5                       Minor Majority
# 7431   ARAEDAU1187B9917DE                           Mira Craig
# 396    AR0O23H1187FB517D3                     Miracle Fortress
# 10525  AREEQPY1187FB5B9E3                      Miranda Lambert
# 11030  ARF058F1187FB5A712                        Mitchel Musso
# 12308  ARG9IGW1187FB4816E                 Mixtapes & Cellmates
# 4239   AR6AY7W1187B9AC569                         Modest Mouse
# 4049   AR63DJ41187FB4056D                             Mojave 3
# 5244   AR7BRPP1187B992AC1                               Moneen
# 5385   AR7H65U1187FB3FA23         Monkey Swallows The Universe
# 8064   ARB50UG1187FB572C9                             Moriarty
# 6135   AR8N7GO1187B989024                             Mr Flash
# 12320  ARGBR4I1187B99D073                             Mudhoney
# 10561  AREGV3K1187B9AF614                          Mötley Crüe
# 10973  AREZ7Y01187B9B7D19                          Nat Stuckey
# 9846   ARDKVSX1187FB4CCD5                        Natacha Atlas
# 2701   AR40GSU1187FB3AA01                         Neil Diamond
# 12912  ARH2BAK1187B9895F3                        Neil Halstead
# 741    AR14K4J1187B993B60                            Neko Case
# 6136   AR8N8XT1187FB4DAD9                          Neva Dinova
# 8901   ARCF9DS1187B9B76C1                       New Model Army
# 7179   AR9YH7P1187FB4CCE2                        Nicole Atkins
# 1554   AR2DTUT1187FB423B4                        Niels Frevert
# 6218   AR8RDYA1187FB440D9                      Nikola Sarcevic
# 2747   AR41OIB1187B99A19D                         Nils Lofgren
# 3381   AR52NSC1187B98F66D                        Nina Nastasia
# 7428   ARAE6571187FB44219                        Nino D'Angelo
# 11412  ARFELOH1187B991F95                           Niraj Chag
# 3708   AR5KO5B1187B98F7D8                         Niña Pastori
# 2360   AR3NZDQ1187FB3A628                                Nneka
# 9350   ARD3SIZ1187B9A093D                       Noah Georgeson
# 8314   ARBJ22B1187B9AD31C                          Norah Jones
# 9735   ARDD00U1187B9AEB3F                           Obie Trice
# 9767   ARDDKCH11E2835D167                            Oi Va Voi
# 7823   ARAZP5N1187B9B4D5D                       Okkervil River
# 4405   AR6E3PI1187FB457C1                          Ola Podrida
# 11813  ARFNHSA1187FB36A5C                             Ole Paus
# 160    AR0BGM11187B9B09BA                   Olivia Newton-John
# 3754   AR5NY3Y1187FB4DCDF                          Otros Aires
# 4200   AR6A5RI1187FB39625                       Over The Rhine
# 970    AR1MWSF1187B9A66E2                        Parkway Drive
# 5860   AR8B7SK1187FB5322E                            Pat Green
# 12399  ARGDSO91187B9AAB35                        Patrick Bruel
# 9718   ARDC81X1187B989EB9                        Patti Scialfa
# 4536   AR6I54S1187FB48C6B                        Patty Griffin
# 11986  ARFVYJI1187B9B8E13                            Pearl Jam
# 10572  AREH9861187FB4BE21                       Persiana Jones
# 726    AR138US119B340375E                        Pete Molinari
# 5936   AR8GNAZ1187FB3B789                  Peter Bradley Adams
# 3532   AR58TT71187FB4D2F7                      Peter Broderick
# 7738   ARAW99S1187B9B6EBF                            Phil Ochs
# 2413   AR3Q7431187B9B30D9                          Piano Magic
# 11819  ARFQ5GF1187FB38DE3                    Pink Mountaintops
# 1844   AR2YE121187B993677                            Pinmonkey
# 8393   ARBJT8G11C8A422C93                       Plastique Noir
# 9227   ARCYXKG1187B98FCF6                                 Pnau
# 10547  AREFZF31187B998A93                             Po' Girl
# 8594   ARBYKYC1187B99A03B                       Polly Paulusma
# 12175  ARG2UZ71187FB4FF5C                       Porter Wagoner
# 5549   AR7RU731187B9AA490                                Povia
# 878    AR1EJ9R119B3403912                       Punch Brothers
# 10347  ARE56H21187FB5361D                          Rachid Taha
# 9358   ARD3WVY1187B9A154E                       Railroad Earth
# 5926   AR8FVLR1187FB57C3C                        Rainald Grebe
# 8925   ARCGWCS1187FB3F25B                Ramblin' Jack Elliott
# 1773   AR2WN631187B99DA0B                    Randy Rogers Band
# 5652   AR7ZFLN1187FB4830A                        Rascal Flatts
# 951    AR1LYBP1187FB3F510                            Raul Malo
# 6349   AR90WS41187FB3F064                       Ray LaMontagne
# 6639   AR9BP2I1187FB3708F                         Raz Dwa Trzy
# 6697   AR9HFVQ1187FB4CF6B                        Richard Swift
# 9524   ARD94MR11C8A42B029                      Richie McDonald
# 10713  ARENMIP1187FB5638D                      Robbie Williams
# 9036   ARCKOVU11F4C83E9A7                     Robert Earl Keen
# 5930   AR8GAJA1187B9B557D                      Robyn Hitchcock
# 10800  AREPWXH1187B99019B                         Roch Voisine
# 7196   ARA03YI1187FB46B00                   Rock Plaza Central
# 7210   ARA2YV71187FB3B225                       Rocky Votolato
# 3638   AR5FIDV1187FB50D40        Roger Clyne & The Peacemakers
# 4617   AR6OSQ81187FB3FDAB                        Ronan Keating
# 12586  ARGIABO1187FB4B3B5                        Ronnie Milsap
# 1946   AR3430G1187B99261A                          Rosa Passos
# 2425   AR3R83L1187B9B01B0                         Rosanne Cash
# 6475   AR958JT1187B9B9863                         Rosie Thomas
# 8560   ARBVFK31187B9A365B                       Ross Copperman
# 8869   ARC9Y481187B990259                              Roxette
# 11896  ARFSZXM1187FB5A941                          Roy Orbison
# 5970   AR8HI8C1187B9B31F6                       Ruben Studdard
# 8246   ARBGDF21187FB49FE8                         Rufus Thomas
# 2497   AR3TZ691187FB3DBB1                       Russell Watson
# 713    AR12MYU1187B9AE31D                        Ruthie Foster
# 12512  ARGHBVV1187FB4D57A                           Ryan Adams
# 10936  AREYHBH1187FB4537B                         Ryan Bingham
# 5458   AR7N7MI1187FB46935                                 Sade
# 8614   ARBZ5F71187B9A5860                             Sam Bush
# 6363   AR918KK1187B99E9F2                             Sandrine
# 11656  ARFLHWV1187FB4E77F                          Sandy Posey
# 11839  ARFR3E51187B9A0A85                           Sara Evans
# 6473   AR94S1H11C8A42C48B                             Sara Lov
# 3105   AR4PZGW1187FB4FF50  Sarah Borges and the Broken Singles
# 6252   AR8U15Z11C8A42AE9A                          Sarah Johns
# 10809  AREQGNM1187B996DD3                        Schrottgrenze
# 301    AR0LTQV1187B9B6079                   Shakespears Sister
# 4692   AR6PJ8R1187FB5AD70                              Shakira
# 1162   AR1UBAL1187FB4A2DF                         Shannon Noll
# 11369  ARFCYCX1187FB3A704                              Shantel
# 9906   ARDPYMW1229890073F                     Sharon Van Etten
# 10041  ARDW5AW1187FB55708                         Shawn Colvin
# 1630   AR2QUH81187B990573                                Shazz
# 2594   AR3X6YL1187B9A44A0                            She & Him
# 7238   ARA3VJJ1187FB3F5A6                         Shelby Lynne
# 1486   AR2C54R1187B993B4C                          Sheryl Crow
# 6843   AR9MCC71187FB3BE9D                      Shout Out Louds
# 1279   AR1YWN01187FB55249                        Show Of Hands
# 2850   AR48SFC1187FB39732                        Sibylle Baier
# 810    AR190KO1187B9905EC                         Sick Puppies
# 10786  AREPD8D1187FB3F5BC                         Sister Hazel
# 11810  ARFN3YG1187B9AD9F1                            Skyforger
# 10226  ARE2QID1187B98FA19                    Sleepy John Estes
# 8680   ARC1VSF1187FB511DA                                Sloan
# 10884  AREV5ZI1187B992CF8                             Slowride
# 262    AR0JKDD1187B9BA274                        Snooks Eaglin
# 11323  ARFCET51187FB3613E                          So They Say
# 12402  ARGE4J31187B9B41EE                       Sofia Karlsson
# 4163   AR65Y8H1187FB38CFD                        Solomon Burke
# 434    AR0PYX81187FB3C438                          Sondaschule
# 11850  ARFREWD1187FB41079                        Sondre Lerche
# 6659   AR9FX3G1187FB3EEC4                        Sondre Lerche
# 407    AR0OPP01187FB3C863                       Sonya Kitchell
# 5920   AR8FJPT1187B9B70AA                              Soulive
# 5641   AR7YY9H1187FB37416                     Southeast Engine
# 10088  ARDW9P51187B9A9B0B                  Soweto Gospel Choir
# 5602   AR7VWZ11187B98DA42                          Spice Girls
# 8658   ARC0ANR1187FB4E291                              Spinvis
# 1084   AR1R15M1187B9AEB0D                        Spiritualized
# 9925   ARDRJSP126E2B3BEF8                        Spiritualized
# 9923   ARDQQIL126A031DF10                        Standard Fare
# 12955  ARH65291187B989DB5                         Starflyer 59
# 7280   ARA4M9N1187B9AF09C                     Stephen Fretwell
# 7208   ARA2J4X1187B9B7FEF                       Stephen Stills
# 2995   AR4IWYN1187FB47DF6                               Strata
# 2787   AR43QZX1187B98D2F6    Suburban Kids With Biblical Names
# 7225   ARA3NYL1187FB55DA7                      Subway To Sally
# 11631  ARFL99B1187B9A2A45                            Sugarland
# 8893   ARCE1KK1187FB3C9F1                          Superfamily
# 4038   AR62DYJ1187FB4F833                         Supersuckers
# 12886  ARH04ED1187FB37E72                       Susan Aglukark
# 11552  ARFJLDJ12086C16AC4                         Susie Arioli
# 3426   AR557N41187FB3E67F                      Swallow The Sun
# 3404   AR53H581187B9A93F9                         Sylvie Lewis
# 3382   AR53F4O1187B9A0121                            Tahiti 80
# 9885   ARDNY8K1187FB4CC9E                       Taken By Trees
# 11663  ARFLNP11187FB371E1                               Takida
# 9975   ARDS7G91187B992D5E                          Takka Takka
# 12836  ARGWWVA11E2835DEF5                          Tame Impala
# 10485  ARECGP11187B9AC905                        Tanya Donelly
# 3968   AR605YR1187FB3FA7B                         Tara MacLean
# 8282   ARBIBAS1187FB40132                               Tarkio
# 8005   ARB3QEP1187FB4CFC6          Ted Leo and the Pharmacists
# 6955   AR9OGG71187FB40520                               Teitur
# 9448   ARD7I1Q1187B991550                          Terra Naomi
# 8469   ARBTDXS11E2835CEC6                 The Alternate Routes
# 7194   AR9ZN601187FB3CBAE                          The Autumns
# 477    AR0QQGK1187FB4D5CB                   The Avett Brothers
# 624    AR0XFXQ1187B98C49F                        The Bachelors
# 5884   AR8CZ1U1187FB4CED1                   The Be Good Tanyas
# 602    AR0V36F1187FB366B1                       The Chieftains
# 12148  ARG2QEC1187B9B7FDB                        The Clientele
# 6172   AR8OVZ01187B9A5E1A                        The Dirtbombs
# 384    AR0NH5R1187B9A47C9                    The Divine Comedy
# 7055   AR9R6911187B9B250A                            The Duhks
# 5597   AR7V22R1187FB41F76                            The Ergs!
# 8571   ARBVLCJ1187FB50E61                  The Gaslight Anthem
# 1046   AR1QSM61187FB3C9EC                        The Good Life
# 10313  ARE4SXN1187FB38701                           The Gourds
# 1949   AR34BO71187B9AD988                         The Grascals
# 8205   ARBF7L91187B9B716A                  The Handsome Family
# 802    AR16V6G1187FB56192                   The Helio Sequence
# 5797   AR89NF11187FB37A94                   The Hidden Cameras
# 11041  ARF10P71187FB44F32                        The Holloways
# 6763   AR9KQMJ1187FB577BE           The Infamous Stringdusters
# 1976   AR358YS1187FB44A29                      The Jordanaires
# 2098   AR3EPSZ1187B997170                       The Lemonheads
# 2067   AR3CGRF1187FB37FA9                       The Lilac Time
# 7450   ARAFLZ01187B99D8DF                   The Little Willies
# 8449   ARBRL2P1187B9AF9E4                       The Lucksmiths
# 1959   AR34XEI1187FB4BE06                     The Midway State
# 35     AR01HKT1187B996F26                   The Mountain Goats
# 11430  ARFF4B41187FB48151                The New Pornographers
# 642    AR0ZJGR1187B98F5BA                           The Panics
# 12862  ARGZE0X1187FB430E5                        The RH Factor
# 1303   AR20F0N1187FB4DEE2                  The Republic Tigers
# 6526   AR95XYH1187FB53951                        The Residents
# 6028   AR8ILP91187B9B3AE1                     The Road Hammers
# 668    AR11NP91187B9901B4                           The Roches
# 11348  ARFCUN31187B9AD578                   The Rolling Stones
# 5583   AR7UCAA119B8668A2B          The Rural Alberta Advantage
# 10219  ARE2F7G1187B9A25B0               The Scourge Of The Sea
# 12927  ARH37AU1187B9A3CD9                    The Shortwave Set
# 6948   AR9O98A1187FB39621                          The Strokes
# 7645   ARARKND1187B990A9C                         The Subdudes
# 10503  AREDB6Z11C8A414ED0                   The Sunny Cowgirls
# 10504  AREDHSB1187FB57583             The Tallest Man On Earth
# 12287  ARG733S1187B99AD70                         The Toasters
# 5792   AR88M4Q1187B9B752F                      The Weakerthans
# 3677   AR5HMXP119B86693D8                    The Week That Was
# 5409   AR7I0UN1187B9913B3                       The Wilkinsons
# 7485   ARAFZCC1187B9B92C3                           The Zutons
# 1034   AR1Q55Q1187FB41944                      This Is The Kit
# 2083   AR3CZP01187FB476CA                            Thom Hell
# 1101   AR1STU51187FB50050                       Thomas Dybdahl
# 1336   AR227JP1187FB375BC                         Tift Merritt
# 10667  AREMPER1187B9AEB42                            Tiger Lou
# 12259  ARG5STF1187FB4902A                             Timbuktu
# 12087  ARFWYS91187B988BBC                            Timesbold
# 4171   AR66MG71187B9AB2E1                    Timothy B. Schmit
# 2819   AR45UNF1187FB45AD8                           Tina Arena
# 8224   ARBFY7A119B8669827                     Titus Andronicus
# 3048   AR4K4NW1187B9AF09B                           Tom Baxter
# 9148   ARCRFWB1187FB396E4                            Tom McRae
# 3192   AR4R5HW1187FB465E8                          Tom Russell
# 10842  ARERLPG1187FB3BB39                            Tom Waits
# 3345   AR4ZNBW1187FB554B8                         Tony Bennett
# 9229   ARCZ20M1187FB49687                       Tony Joe White
# 10368  ARE5S2X1187FB4CA15                  Totalt Jävla Mörker
# 2036   AR3AY3R1187FB52CF0                           Tracy Byrd
# 7754   ARAX0621187B9A5B54                        Trent Willmon
# 6099   AR8LVM51187B996756                  Trespassers William
# 8547   ARBUV6L1187B98B8A9                           Turbonegro
# 5751   AR83T1H1187B99FA5F                         Turin Brakes
# 12989  ARH6IUC1187B9A98E7                       Two Cow Garage
# 2672   AR3ZARK1187FB4CC5E                       Térez Montcalm
# 1185   AR1WWVL1187B9B0306                                 UB40
# 2082   AR3CTQW1187FB37398                           Uncle Earl
# 727    AR13ZKG1187B99BD42                         Val Doonican
# 9050   ARCLH8B1187B9AB7A3                           Val Emmich
# 1197   AR1X9I91187FB36254                          Vanden Plas
# 4566   AR6JY3I1187B98DAF7                        Vanilla Fudge
# 8364   ARBJB2S1187B9BA2CB                              Vetiver
# 3948   AR603HK1187FB3F855                         Vic Chesnutt
# 6757   AR9J9XL1187FB4DFEF                         Von Südenfed
# 11262  ARFB0EY1187FB597C7                           Washington
# 3215   AR4RY4E1187B9912E5                           Wax Poetic
# 7802   ARAZ59E1187B98BF6D                          Webb Wilder
# 5707   AR82FM11187FB37758                            Will Hoge
# 5154   AR768NN1187B99D172                     William Basinski
# 1019   AR1PQST1187FB4D913                         William Bell
# 8700   ARC2NOM1187FB426C6                  William Fitzsimmons
# 11386  ARFDIVY1187B9A2B66                          Willy Mason
# 4027   AR617PT1187FB504AC                               Winger
# 5684   AR81IMB1187B990DF1                          Wintersleep
# 12745  ARGNUE61187B9B0F61                            Wovenhand
# 10771  AREP8SG1187FB3C6EC                   Wrinkle Neck Mules
# 1016   AR1PC9R1187B9ACC9A                         Yann Tiersen
# 3892   AR5UHAH1187B9A0B92                      Ying Yang Twins
# 7728   ARAUIJP1187FB3DD95                             You Am I
# 7344   ARA6H4G1187B99E2F2                         Youn Sun Nah
# 8183   ARBETGK12420782876                      Young Rebel Set
# 111    AR0757Q119B3403C71                            Your Hero
# 2466   AR3SDNY1187B991573                          Youth Group
# 5332   AR7D85S1187FB372A2                    Zacarias Ferreira
# 1711   AR2UK4K11A348F01EC                           honeyhoney
# 1702   AR2U9YY1187B9955A4                            k.d. lang

# %%
dfCountry = dfCountry[pd.notnull(dfCountry.tags)].reset_index(drop=True)

# %% [markdown]
# #### Populate Genre, Country_Count, Pop_Count, Other_Count columns

# %%
#call getGenre to populate features and counts

dfCountry = getGenre(dfCountry)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d64c93fa477b> in <module>()
#       1 #call getGenre to populate features and counts
#       2
# ----> 3 dfCountry = getGenre(dfCountry)
#
# NameError: name 'dfCountry' is not defined

# %%
dfCountry.head()
# Out:
#    level_0  index           artist_id                             tags  \
# 0        0      0  AR00B1I1187FB433EB                [(country rock,)]
# 1        1      1  AR00B1I1187FB433EB                [(country rock,)]
# 2        2      2  AR00J9R1187B98D920  [(country gospel,), (country,)]
# 3        3      3  AR00J9R1187B98D920  [(country gospel,), (country,)]
# 4        4      4  AR00J9R1187B98D920  [(country gospel,), (country,)]
#
#              track_id                title             song_id  \
# 0  TRHYMAO128E0792260        Crashing Down  SOAHIFF12A6701E01B
# 1  TRQCBTB128E079225F       Feels So Right  SONAEPC12A6701E01A
# 2  TRBUNNH128F932E25F          Space Pt. 5  SOXMPDS12AB0181393
# 3  TRBLRQM128F932E231  Time Is Running Out  SODLFKY12AB0187BD6
# 4  TRFAMCY128F932E22A        Fresh As That  SOFSYJL12AB0187BBC
#
#                release                           artist_mbid  \
# 0             Sub Rosa  4a5777b3-f55b-437c-8b23-d9ee7791c7fc
# 1             Sub Rosa  4a5777b3-f55b-437c-8b23-d9ee7791c7fc
# 2  Time Is Running Out  41da462e-e441-4bc0-952b-5a66387df5be
# 3  Time Is Running Out  41da462e-e441-4bc0-952b-5a66387df5be
# 4  Time Is Running Out  41da462e-e441-4bc0-952b-5a66387df5be
#
#         artist_name     ...                          id  \
# 0  Eagle-Eye Cherry     ...      30SxJBAOgFVIT7ZsWNhA0T
# 1  Eagle-Eye Cherry     ...      3rEXei8vuirQ6V3pzzDafE
# 2        Farm Fresh     ...      2dw9TO8A7YSwfP8gDjeZAP
# 3        Farm Fresh     ...      4JAYSrK78qTC8u3pE0qlGC
# 4        Farm Fresh     ...      3CIrY2AXTQ7JLd6XMSG2v1
#
#                                     uri  \
# 0  spotify:track:30SxJBAOgFVIT7ZsWNhA0T
# 1  spotify:track:3rEXei8vuirQ6V3pzzDafE
# 2  spotify:track:2dw9TO8A7YSwfP8gDjeZAP
# 3  spotify:track:4JAYSrK78qTC8u3pE0qlGC
# 4  spotify:track:3CIrY2AXTQ7JLd6XMSG2v1
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/30SxJBAOgFVI...
# 1  https://api.spotify.com/v1/tracks/3rEXei8vuirQ...
# 2  https://api.spotify.com/v1/tracks/2dw9TO8A7YSw...
# 3  https://api.spotify.com/v1/tracks/4JAYSrK78qTC...
# 4  https://api.spotify.com/v1/tracks/3CIrY2AXTQ7J...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/30Sx...     322067.0
# 1  https://api.spotify.com/v1/audio-analysis/3rEX...     261040.0
# 2  https://api.spotify.com/v1/audio-analysis/2dw9...     285067.0
# 3  https://api.spotify.com/v1/audio-analysis/4JAY...     222773.0
# 4  https://api.spotify.com/v1/audio-analysis/3CIr...     231067.0
#
#    time_signature    genre country_count pop_count other_count
# 0             4.0  country           1.0       0.0         0.0
# 1             4.0  country           1.0       0.0         0.0
# 2             4.0  country           2.0       0.0         0.0
# 3             4.0  country           2.0       0.0         0.0
# 4             4.0  country           2.0       0.0         0.0
#
# [5 rows x 42 columns]

# %%
dfCountry[dfCountry.artist_id == 'AR65K7A1187FB4DAA4']
# Out:
#       level_0  index           artist_id          tags            track_id  \
# 4049     4083   4083  AR65K7A1187FB4DAA4  [(country,)]  TRMHLAL128F92D5D3A
# 4050     4084   4084  AR65K7A1187FB4DAA4  [(country,)]  TRWRRFC128F931FD82
# 4051     4085   4085  AR65K7A1187FB4DAA4  [(country,)]  TRWJCLJ128F42B84A1
# 4052     4086   4086  AR65K7A1187FB4DAA4  [(country,)]  TRGQFUZ128F92ED646
# 4053     4087   4087  AR65K7A1187FB4DAA4  [(country,)]  TRGNSTB128F92D5D39
# 4054     4088   4088  AR65K7A1187FB4DAA4  [(country,)]  TRGLRYX128F9340D39
# 4055     4089   4089  AR65K7A1187FB4DAA4  [(country,)]  TRGELPA128F9327BCF
# 4056     4090   4090  AR65K7A1187FB4DAA4  [(country,)]  TRGXSEO128F92E5880
# 4057     4091   4091  AR65K7A1187FB4DAA4  [(country,)]  TRGKIAX128F92FFC89
# 4058     4092   4092  AR65K7A1187FB4DAA4  [(country,)]  TRHQYDD128F92E5882
# 4059     4093   4093  AR65K7A1187FB4DAA4  [(country,)]  TRCZMLQ128F9307825
# 4060     4094   4094  AR65K7A1187FB4DAA4  [(country,)]  TRCZZJN128F92ED652
# 4061     4095   4095  AR65K7A1187FB4DAA4  [(country,)]  TRCPXID128F92D5D3C
# 4062     4096   4096  AR65K7A1187FB4DAA4  [(country,)]  TRCVCTZ128F425B552
# 4063     4097   4097  AR65K7A1187FB4DAA4  [(country,)]  TRCVIWD128F92FFC83
# 4064     4098   4098  AR65K7A1187FB4DAA4  [(country,)]  TRRHXBF128F92FFC91
# 4065     4099   4099  AR65K7A1187FB4DAA4  [(country,)]  TRRFAYO128F9324F33
# 4066     4100   4100  AR65K7A1187FB4DAA4  [(country,)]  TRBPIMI128F931D01D
# 4067     4101   4101  AR65K7A1187FB4DAA4  [(country,)]  TRBLSLM12903CD82E9
# 4068     4102   4102  AR65K7A1187FB4DAA4  [(country,)]  TRFCTQO128F92D5D3B
# 4069     4103   4103  AR65K7A1187FB4DAA4  [(country,)]  TRFAHUU128F92F383F
# 4070     4104   4104  AR65K7A1187FB4DAA4  [(country,)]  TRQZCAB128F42727E2
# 4071     4105   4105  AR65K7A1187FB4DAA4  [(country,)]  TRZBDJG128F42727D2
# 4072     4106   4106  AR65K7A1187FB4DAA4  [(country,)]  TRZNAAQ128F42BB7BF
# 4073     4107   4107  AR65K7A1187FB4DAA4  [(country,)]  TRZLRZJ128F931FD8D
# 4074     4108   4108  AR65K7A1187FB4DAA4  [(country,)]  TRZEOUN12903CD82E6
# 4075     4109   4109  AR65K7A1187FB4DAA4  [(country,)]  TRIQCXJ12903CDAFF4
# 4076     4110   4110  AR65K7A1187FB4DAA4  [(country,)]  TRIPVVB128F933A417
# 4077     4111   4111  AR65K7A1187FB4DAA4  [(country,)]  TRITGBY128F42800BB
# 4078     4112   4112  AR65K7A1187FB4DAA4  [(country,)]  TRIEFVH12903CD0658
# ...       ...    ...                 ...           ...                 ...
# 4083     4117   4117  AR65K7A1187FB4DAA4  [(country,)]  TRPMJYT128F931CE8F
# 4084     4118   4118  AR65K7A1187FB4DAA4  [(country,)]  TRPDNZQ128F92C1E98
# 4085     4119   4119  AR65K7A1187FB4DAA4  [(country,)]  TRPKXET128F92ED656
# 4086     4120   4120  AR65K7A1187FB4DAA4  [(country,)]  TRTMCJU128F933A414
# 4087     4121   4121  AR65K7A1187FB4DAA4  [(country,)]  TRTWSTA12903CD82EA
# 4088     4122   4122  AR65K7A1187FB4DAA4  [(country,)]  TRULHUP128F9311225
# 4089     4123   4123  AR65K7A1187FB4DAA4  [(country,)]  TRUODCV128F9324F31
# 4090     4124   4124  AR65K7A1187FB4DAA4  [(country,)]  TRLZPDV128F9302C53
# 4091     4125   4125  AR65K7A1187FB4DAA4  [(country,)]  TRLEEPY128F92C1F9A
# 4092     4126   4126  AR65K7A1187FB4DAA4  [(country,)]  TREWCZQ128F425EDD6
# 4093     4127   4127  AR65K7A1187FB4DAA4  [(country,)]  TREZTLT128F92F8550
# 4094     4128   4128  AR65K7A1187FB4DAA4  [(country,)]  TREUTTT128F425EDCC
# 4095     4129   4129  AR65K7A1187FB4DAA4  [(country,)]  TREOYTU128F92E5881
# 4096     4130   4130  AR65K7A1187FB4DAA4  [(country,)]  TRJCKBO128F425EDDC
# 4097     4131   4131  AR65K7A1187FB4DAA4  [(country,)]  TRJRZAK128F931FD83
# 4098     4132   4132  AR65K7A1187FB4DAA4  [(country,)]  TRSNKHK128F427C415
# 4099     4133   4133  AR65K7A1187FB4DAA4  [(country,)]  TRSDVCX12903CB5AA9
# 4100     4134   4134  AR65K7A1187FB4DAA4  [(country,)]  TRVWQXB128F9324F32
# 4101     4135   4135  AR65K7A1187FB4DAA4  [(country,)]  TRVJSPX128F92ED651
# 4102     4136   4136  AR65K7A1187FB4DAA4  [(country,)]  TRVSVNB128F92EF1FF
# 4103     4137   4137  AR65K7A1187FB4DAA4  [(country,)]  TRDCGZE128F9302C4F
# 4104     4138   4138  AR65K7A1187FB4DAA4  [(country,)]  TROIRNT128F92ED644
# 4105     4139   4139  AR65K7A1187FB4DAA4  [(country,)]  TROVJOI128F4260862
# 4106     4140   4140  AR65K7A1187FB4DAA4  [(country,)]  TRXPTDD12903CD82E8
# 4107     4141   4141  AR65K7A1187FB4DAA4  [(country,)]  TRXKVRL128F92ED642
# 4108     4142   4142  AR65K7A1187FB4DAA4  [(country,)]  TRKCUMT128F42727E5
# 4109     4143   4143  AR65K7A1187FB4DAA4  [(country,)]  TRKNOQB12903CACF1A
# 4110     4144   4144  AR65K7A1187FB4DAA4  [(country,)]  TRKSNOU128F42B853D
# 4111     4145   4145  AR65K7A1187FB4DAA4  [(country,)]  TRYRLGK128F425EDC0
# 4112     4146   4146  AR65K7A1187FB4DAA4  [(country,)]  TRYAJZI128F42727D5
#
#                             title             song_id  \
# 4049                         Halo  SONQBQA12A8C141D2C
# 4050                  Green Light  SOSYXDE12A8AE45E45
# 4051          Encore For The Fans  SOSEABB12AF72A0F70
# 4052  That's Why You're Beautiful  SORBUNE12AB017CDD2
# 4053                         Halo  SOGXLJB12A8C141D21
# 4054                       Poison  SOFXOAX12AB0181A75
# 4055                 Naughty Girl  SOPXVXL12A58A7EDF3
# 4056                Irreplaceable  SOZQKLX12A8C1436CF
# 4057           Once In A Lifetime  SOHABYI12AF72A9C93
# 4058                Irreplaceable  SOIQRCE12A8C1436D6
# 4059                Crazy In Love  SOFMHKW12A6D4F4F8B
# 4060                        Hello  SOXMARU12AB017CDF7
# 4061                         Halo  SOADJQJ12A8C141D38
# 4062                  Green Light  SOUERHH12A8AE47F65
# 4063                      At Last  SOPDRJZ12AF72A6CE5
# 4064          I'd Rather Go Blind  SOGKHOV12AF72A7875
# 4065                 Sweet Dreams  SOSDGUX12AB01802FE
# 4066                          Yes  SOFRPWV12AB017E58C
# 4067                  Video Phone  SOYBIHE12AB018835D
# 4068                         Halo  SOSEGOB12A8C141D2F
# 4069                Get Me Bodied  SOFSGBJ12A8AE4645B
# 4070            Beyoncé Interlude  SOWYETX12A8C13464E
# 4071          Dangerously In Love  SORWBEB12A58A78BF8
# 4072                Irreplaceable  SOLVSWA12AF72A2C5F
# 4073               Ring The Alarm  SOGUUQH12A8C1427D6
# 4074                  Video Phone  SOAZCPY12AB0188357
# 4075                        Fever  SOMOBNC12AB018746E
# 4076                 Sweet Dreams  SOWCAMG12AB0181DC8
# 4077                     Baby Boy  SOIFXQV12A8C134F7C
# 4078                      At Last  SOOGBKL12AB0187D25
# ...                           ...                 ...
# 4083                 Naughty Girl  SOBCNHX12AB018136C
# 4084                Freakum Dress  SOCELEG12AF72A7052
# 4085                          Ego  SOJGSFH12AB017EFC2
# 4086                 Sweet Dreams  SONYJYD12AB0181DBD
# 4087                  Video Phone  SOHQYGM12AB018835E
# 4088                Get Me Bodied  SOEZQYZ12AF729F536
# 4089                 Sweet Dreams  SOHSSSJ12A8C141517
# 4090       All I Could Do Was Cry  SOZUUZN12A58A7AF12
# 4091                Irreplaceable  SORHUHE12A8C1436E6
# 4092                   Speechless  SOIMTIH12A8AE46285
# 4093                         Diva  SOMOGQW12A8C142044
# 4094                Flaws And All  SOLMQFQ12A8AE46269
# 4095                Irreplaceable  SOOUGTG12A8C1436D3
# 4096                  Check On It  SOEOMEJ12A8AE46299
# 4097                    Kitty Kat  SOUODFE12A58A80347
# 4098                        Fever  SOOULRX12A8C137BFA
# 4099               Ring The Alarm  SOIOYQR12AB01889E4
# 4100                 Sweet Dreams  SOQEWGG12AB01850B3
# 4101                  Video Phone  SOSHQHA12A58A7B1E9
# 4102                         Diva  SOZXHNM12AB017CDEA
# 4103                  Trust In Me  SOXCACX12AB018607D
# 4104               Smash Into You  SOOYDMX12A58A7A1EE
# 4105                Flaws And All  SOHZCDT12A582912D6
# 4106                  Video Phone  SOXXRNF12AB018835B
# 4107                    Ave Maria  SOWDCXZ12AB017CDC8
# 4108                   Speechless  SOEJEEH12A8C134658
# 4109                         Halo  SONKGOD12A58A79778
# 4110                Get Me Bodied  SOPCLSY12A8C13E413
# 4111                Freakum Dress  SOSZCCZ12A8AE488CB
# 4112                 Naughty Girl  SOVFBUL12A58A7B498
#
#                                                 release  \
# 4049                                               Halo
# 4050                               B'Day Deluxe Edition
# 4051                                              B'Day
# 4052                                I AM...SASHA FIERCE
# 4053                                               Halo
# 4054               I AM...SASHA FIERCE THE BONUS TRACKS
# 4055                                       Naughty Girl
# 4056                            Irreplaceable (remixes)
# 4057     Music From The Motion Picture Cadillac Records
# 4058                            Irreplaceable (remixes)
# 4059                                      Crazy In Love
# 4060                                I AM...SASHA FIERCE
# 4061                                               Halo
# 4062                                        Green Light
# 4063     Music From The Motion Picture Cadillac Records
# 4064     Music From The Motion Picture Cadillac Records
# 4065                                       Sweet Dreams
# 4066                                Dangerously In Love
# 4067                                        Video Phone
# 4068                                               Halo
# 4069                                     Irreemplazable
# 4070                                Dangerously In Love
# 4071                                Dangerously In Love
# 4072                                      Irreplaceable
# 4073                               B'Day Deluxe Edition
# 4074                                        Video Phone
# 4075                                              Fever
# 4076             Ego/Sweet Dreams Singles & Dance Mixes
# 4077                                           Baby Boy
# 4078                                            At Last
# ...                                                 ...
# 4083                                       Naughty Girl
# 4084                               B'Day Deluxe Edition
# 4085                                I AM...SASHA FIERCE
# 4086             Ego/Sweet Dreams Singles & Dance Mixes
# 4087                                        Video Phone
# 4088                                              B'Day
# 4089                                       Sweet Dreams
# 4090     Music From The Motion Picture Cadillac Records
# 4091                       Listen (from Dreamgirls S/T)
# 4092                  The Beyonce Experience Live Audio
# 4093                      Above And Beyoncé Dance Mixes
# 4094                  The Beyonce Experience Live Audio
# 4095                            Irreplaceable (remixes)
# 4096                  The Beyonce Experience Live Audio
# 4097                               B'Day Deluxe Edition
# 4098  The Fighting Temptations (Music From The Motio...
# 4099                                     Ring The Alarm
# 4100                                       Sweet Dreams
# 4101                                I AM...SASHA FIERCE
# 4102                                I AM...SASHA FIERCE
# 4103     Music From The Motion Picture Cadillac Records
# 4104                                I AM...SASHA FIERCE
# 4105                             Beyoncé Karaoke Hits I
# 4106                                        Video Phone
# 4107                                I AM...SASHA FIERCE
# 4108                                Dangerously In Love
# 4109                                R&B Love Songs 2010
# 4110                                              B'Day
# 4111                  The Beyonce Experience Live Audio
# 4112                                Dangerously In Love
#
#                                artist_mbid artist_name     ...      \
# 4049  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4050  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4051  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4052  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4053  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4054  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4055  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4056  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4057  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4058  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4059  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4060  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4061  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4062  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4063  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4064  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4065  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4066  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4067  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4068  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4069  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4070  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4071  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4072  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4073  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4074  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4075  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4076  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4077  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4078  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# ...                                    ...         ...     ...
# 4083  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4084  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4085  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4086  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4087  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4088  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4089  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4090  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4091  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4092  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4093  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4094  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4095  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4096  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4097  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4098  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4099  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4100  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4101  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4102  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4103  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4104  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4105  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4106  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4107  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4108  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4109  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4110  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4111  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
# 4112  183105b5-3e68-4748-9086-2c1c11bf7a3d     Beyoncé     ...
#
#                                        uri  \
# 4049  spotify:track:4JehYebiI9JE8sR8MisGVb
# 4050  spotify:track:3JdDBUiZ1UJv7J7RQqxEFF
# 4051  spotify:track:2M16xKUgNTgi8W3Cpv18M2
# 4052  spotify:track:22yMWV37oR5GTuP6XMummO
# 4053  spotify:track:4JehYebiI9JE8sR8MisGVb
# 4054  spotify:track:0yGlYMCTNE1aKRd5YAXEdg
# 4055  spotify:track:0YGQ3hZcRLC5YX7o0hdmHg
# 4056  spotify:track:6RX5iL93VZ5fKmyvNXvF1r
# 4057  spotify:track:4HPfLaqHCxqMmwSg7VXiRt
# 4058  spotify:track:6RX5iL93VZ5fKmyvNXvF1r
# 4059  spotify:track:5IVuqXILoxVWvWEPm82Jxr
# 4060  spotify:track:3ID5lLzkh4uM8XPUuB2VKq
# 4061  spotify:track:4JehYebiI9JE8sR8MisGVb
# 4062  spotify:track:3JdDBUiZ1UJv7J7RQqxEFF
# 4063  spotify:track:0h87GbMRuU8ENP8LmdeA22
# 4064  spotify:track:45eZSR0jA15KPI2HXVSifw
# 4065  spotify:track:1FKxKGONukVFXWVJxAKmlz
# 4066  spotify:track:3m9641nehhPSAIEODgBqaW
# 4067  spotify:track:53hNzjDClsnsdYpLIwqXvn
# 4068  spotify:track:4JehYebiI9JE8sR8MisGVb
# 4069  spotify:track:6fmeXejj4CNkAQ78yao7oE
# 4070  spotify:track:1cfE96qcUYYaSxz1S6Qh6i
# 4071  spotify:track:0KFuXEdOp5QfIfxHR6TJSm
# 4072  spotify:track:6RX5iL93VZ5fKmyvNXvF1r
# 4073  spotify:track:5BkHkyO9PFXs1m7vSMnXp4
# 4074  spotify:track:53hNzjDClsnsdYpLIwqXvn
# 4075  spotify:track:2Y36tgwhi4gykzF0jXwYH2
# 4076  spotify:track:1FKxKGONukVFXWVJxAKmlz
# 4077  spotify:track:4WY3HyGXsWqjFRCVD6gnTe
# 4078  spotify:track:0h87GbMRuU8ENP8LmdeA22
# ...                                    ...
# 4083  spotify:track:0YGQ3hZcRLC5YX7o0hdmHg
# 4084  spotify:track:3IAyQMTYOsspp9p1htFSak
# 4085  spotify:track:6GcuA4J9ruyClBizBd4m5E
# 4086  spotify:track:1FKxKGONukVFXWVJxAKmlz
# 4087  spotify:track:53hNzjDClsnsdYpLIwqXvn
# 4088  spotify:track:6fmeXejj4CNkAQ78yao7oE
# 4089  spotify:track:1FKxKGONukVFXWVJxAKmlz
# 4090  spotify:track:35g7hIs8Jf8tvXPRMSkNPC
# 4091  spotify:track:6RX5iL93VZ5fKmyvNXvF1r
# 4092  spotify:track:3V5I90jseccXcK4MGC1gqr
# 4093  spotify:track:5Ssv6DaKrW0HczVqx6zXdl
# 4094  spotify:track:3REeBOAFzfvSpnzu9ubXmr
# 4095  spotify:track:6RX5iL93VZ5fKmyvNXvF1r
# 4096  spotify:track:79qyhvLo7r5yMopws8Knrn
# 4097  spotify:track:7sk73N1SgNZweS3ozl3NXs
# 4098  spotify:track:2Y36tgwhi4gykzF0jXwYH2
# 4099  spotify:track:5BkHkyO9PFXs1m7vSMnXp4
# 4100  spotify:track:1FKxKGONukVFXWVJxAKmlz
# 4101  spotify:track:53hNzjDClsnsdYpLIwqXvn
# 4102  spotify:track:5Ssv6DaKrW0HczVqx6zXdl
# 4103  spotify:track:67ILUMyAqWmXt80tcskpYK
# 4104  spotify:track:3vi85V6MSvFs0j720UxoAF
# 4105  spotify:track:3REeBOAFzfvSpnzu9ubXmr
# 4106  spotify:track:53hNzjDClsnsdYpLIwqXvn
# 4107  spotify:track:1j9HwUMSkRUeVFRWlHcFsy
# 4108  spotify:track:3V5I90jseccXcK4MGC1gqr
# 4109  spotify:track:4JehYebiI9JE8sR8MisGVb
# 4110  spotify:track:6fmeXejj4CNkAQ78yao7oE
# 4111  spotify:track:3IAyQMTYOsspp9p1htFSak
# 4112  spotify:track:0YGQ3hZcRLC5YX7o0hdmHg
#
#                                              track_href  \
# 4049  https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 4050  https://api.spotify.com/v1/tracks/3JdDBUiZ1UJv...
# 4051  https://api.spotify.com/v1/tracks/2M16xKUgNTgi...
# 4052  https://api.spotify.com/v1/tracks/22yMWV37oR5G...
# 4053  https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 4054  https://api.spotify.com/v1/tracks/0yGlYMCTNE1a...
# 4055  https://api.spotify.com/v1/tracks/0YGQ3hZcRLC5...
# 4056  https://api.spotify.com/v1/tracks/6RX5iL93VZ5f...
# 4057  https://api.spotify.com/v1/tracks/4HPfLaqHCxqM...
# 4058  https://api.spotify.com/v1/tracks/6RX5iL93VZ5f...
# 4059  https://api.spotify.com/v1/tracks/5IVuqXILoxVW...
# 4060  https://api.spotify.com/v1/tracks/3ID5lLzkh4uM...
# 4061  https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 4062  https://api.spotify.com/v1/tracks/3JdDBUiZ1UJv...
# 4063  https://api.spotify.com/v1/tracks/0h87GbMRuU8E...
# 4064  https://api.spotify.com/v1/tracks/45eZSR0jA15K...
# 4065  https://api.spotify.com/v1/tracks/1FKxKGONukVF...
# 4066  https://api.spotify.com/v1/tracks/3m9641nehhPS...
# 4067  https://api.spotify.com/v1/tracks/53hNzjDClsns...
# 4068  https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 4069  https://api.spotify.com/v1/tracks/6fmeXejj4CNk...
# 4070  https://api.spotify.com/v1/tracks/1cfE96qcUYYa...
# 4071  https://api.spotify.com/v1/tracks/0KFuXEdOp5Qf...
# 4072  https://api.spotify.com/v1/tracks/6RX5iL93VZ5f...
# 4073  https://api.spotify.com/v1/tracks/5BkHkyO9PFXs...
# 4074  https://api.spotify.com/v1/tracks/53hNzjDClsns...
# 4075  https://api.spotify.com/v1/tracks/2Y36tgwhi4gy...
# 4076  https://api.spotify.com/v1/tracks/1FKxKGONukVF...
# 4077  https://api.spotify.com/v1/tracks/4WY3HyGXsWqj...
# 4078  https://api.spotify.com/v1/tracks/0h87GbMRuU8E...
# ...                                                 ...
# 4083  https://api.spotify.com/v1/tracks/0YGQ3hZcRLC5...
# 4084  https://api.spotify.com/v1/tracks/3IAyQMTYOssp...
# 4085  https://api.spotify.com/v1/tracks/6GcuA4J9ruyC...
# 4086  https://api.spotify.com/v1/tracks/1FKxKGONukVF...
# 4087  https://api.spotify.com/v1/tracks/53hNzjDClsns...
# 4088  https://api.spotify.com/v1/tracks/6fmeXejj4CNk...
# 4089  https://api.spotify.com/v1/tracks/1FKxKGONukVF...
# 4090  https://api.spotify.com/v1/tracks/35g7hIs8Jf8t...
# 4091  https://api.spotify.com/v1/tracks/6RX5iL93VZ5f...
# 4092  https://api.spotify.com/v1/tracks/3V5I90jseccX...
# 4093  https://api.spotify.com/v1/tracks/5Ssv6DaKrW0H...
# 4094  https://api.spotify.com/v1/tracks/3REeBOAFzfvS...
# 4095  https://api.spotify.com/v1/tracks/6RX5iL93VZ5f...
# 4096  https://api.spotify.com/v1/tracks/79qyhvLo7r5y...
# 4097  https://api.spotify.com/v1/tracks/7sk73N1SgNZw...
# 4098  https://api.spotify.com/v1/tracks/2Y36tgwhi4gy...
# 4099  https://api.spotify.com/v1/tracks/5BkHkyO9PFXs...
# 4100  https://api.spotify.com/v1/tracks/1FKxKGONukVF...
# 4101  https://api.spotify.com/v1/tracks/53hNzjDClsns...
# 4102  https://api.spotify.com/v1/tracks/5Ssv6DaKrW0H...
# 4103  https://api.spotify.com/v1/tracks/67ILUMyAqWmX...
# 4104  https://api.spotify.com/v1/tracks/3vi85V6MSvFs...
# 4105  https://api.spotify.com/v1/tracks/3REeBOAFzfvS...
# 4106  https://api.spotify.com/v1/tracks/53hNzjDClsns...
# 4107  https://api.spotify.com/v1/tracks/1j9HwUMSkRUe...
# 4108  https://api.spotify.com/v1/tracks/3V5I90jseccX...
# 4109  https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 4110  https://api.spotify.com/v1/tracks/6fmeXejj4CNk...
# 4111  https://api.spotify.com/v1/tracks/3IAyQMTYOssp...
# 4112  https://api.spotify.com/v1/tracks/0YGQ3hZcRLC5...
#
#                                            analysis_url  duration_ms  \
# 4049  https://api.spotify.com/v1/audio-analysis/4Jeh...     261640.0
# 4050  https://api.spotify.com/v1/audio-analysis/3JdD...     210240.0
# 4051  https://api.spotify.com/v1/audio-analysis/2M16...      39880.0
# 4052  https://api.spotify.com/v1/audio-analysis/22yM...     221467.0
# 4053  https://api.spotify.com/v1/audio-analysis/4Jeh...     261640.0
# 4054  https://api.spotify.com/v1/audio-analysis/0yGl...     244893.0
# 4055  https://api.spotify.com/v1/audio-analysis/0YGQ...     208573.0
# 4056  https://api.spotify.com/v1/audio-analysis/6RX5...     227853.0
# 4057  https://api.spotify.com/v1/audio-analysis/4HPf...     239533.0
# 4058  https://api.spotify.com/v1/audio-analysis/6RX5...     227853.0
# 4059  https://api.spotify.com/v1/audio-analysis/5IVu...     236133.0
# 4060  https://api.spotify.com/v1/audio-analysis/3ID5...     256533.0
# 4061  https://api.spotify.com/v1/audio-analysis/4Jeh...     261640.0
# 4062  https://api.spotify.com/v1/audio-analysis/3JdD...     210240.0
# 4063  https://api.spotify.com/v1/audio-analysis/0h87...     180707.0
# 4064  https://api.spotify.com/v1/audio-analysis/45eZ...     190080.0
# 4065  https://api.spotify.com/v1/audio-analysis/1FKx...     208067.0
# 4066  https://api.spotify.com/v1/audio-analysis/3m96...     259067.0
# 4067  https://api.spotify.com/v1/audio-analysis/53hN...     215440.0
# 4068  https://api.spotify.com/v1/audio-analysis/4Jeh...     261640.0
# 4069  https://api.spotify.com/v1/audio-analysis/6fme...     205813.0
# 4070  https://api.spotify.com/v1/audio-analysis/1cfE...      16373.0
# 4071  https://api.spotify.com/v1/audio-analysis/0KFu...     293133.0
# 4072  https://api.spotify.com/v1/audio-analysis/6RX5...     227853.0
# 4073  https://api.spotify.com/v1/audio-analysis/5BkH...     203347.0
# 4074  https://api.spotify.com/v1/audio-analysis/53hN...     215440.0
# 4075  https://api.spotify.com/v1/audio-analysis/2Y36...     212893.0
# 4076  https://api.spotify.com/v1/audio-analysis/1FKx...     208067.0
# 4077  https://api.spotify.com/v1/audio-analysis/4WY3...     244827.0
# 4078  https://api.spotify.com/v1/audio-analysis/0h87...     180707.0
# ...                                                 ...          ...
# 4083  https://api.spotify.com/v1/audio-analysis/0YGQ...     208573.0
# 4084  https://api.spotify.com/v1/audio-analysis/3IAy...     200533.0
# 4085  https://api.spotify.com/v1/audio-analysis/6Gcu...     236360.0
# 4086  https://api.spotify.com/v1/audio-analysis/1FKx...     208067.0
# 4087  https://api.spotify.com/v1/audio-analysis/53hN...     215440.0
# 4088  https://api.spotify.com/v1/audio-analysis/6fme...     205813.0
# 4089  https://api.spotify.com/v1/audio-analysis/1FKx...     208067.0
# 4090  https://api.spotify.com/v1/audio-analysis/35g7...     190400.0
# 4091  https://api.spotify.com/v1/audio-analysis/6RX5...     227853.0
# 4092  https://api.spotify.com/v1/audio-analysis/3V5I...     360493.0
# 4093  https://api.spotify.com/v1/audio-analysis/5Ssv...     200613.0
# 4094  https://api.spotify.com/v1/audio-analysis/3REe...     249173.0
# 4095  https://api.spotify.com/v1/audio-analysis/6RX5...     227853.0
# 4096  https://api.spotify.com/v1/audio-analysis/79qy...     210427.0
# 4097  https://api.spotify.com/v1/audio-analysis/7sk7...     235680.0
# 4098  https://api.spotify.com/v1/audio-analysis/2Y36...     212893.0
# 4099  https://api.spotify.com/v1/audio-analysis/5BkH...     203347.0
# 4100  https://api.spotify.com/v1/audio-analysis/1FKx...     208067.0
# 4101  https://api.spotify.com/v1/audio-analysis/53hN...     215440.0
# 4102  https://api.spotify.com/v1/audio-analysis/5Ssv...     200613.0
# 4103  https://api.spotify.com/v1/audio-analysis/67IL...     224427.0
# 4104  https://api.spotify.com/v1/audio-analysis/3vi8...     271613.0
# 4105  https://api.spotify.com/v1/audio-analysis/3REe...     249173.0
# 4106  https://api.spotify.com/v1/audio-analysis/53hN...     215440.0
# 4107  https://api.spotify.com/v1/audio-analysis/1j9H...     221653.0
# 4108  https://api.spotify.com/v1/audio-analysis/3V5I...     360493.0
# 4109  https://api.spotify.com/v1/audio-analysis/4Jeh...     261640.0
# 4110  https://api.spotify.com/v1/audio-analysis/6fme...     205813.0
# 4111  https://api.spotify.com/v1/audio-analysis/3IAy...     200533.0
# 4112  https://api.spotify.com/v1/audio-analysis/0YGQ...     208573.0
#
#       time_signature    genre  genre_list country_count pop_count other_count
# 4049             4.0  country   [country]           1.0       0.0         0.0
# 4050             4.0  country   [country]           1.0       0.0         0.0
# 4051             4.0  country   [country]           1.0       0.0         0.0
# 4052             4.0  country   [country]           1.0       0.0         0.0
# 4053             4.0  country   [country]           1.0       0.0         0.0
# 4054             4.0  country   [country]           1.0       0.0         0.0
# 4055             4.0  country   [country]           1.0       0.0         0.0
# 4056             4.0  country   [country]           1.0       0.0         0.0
# 4057             3.0  country   [country]           1.0       0.0         0.0
# 4058             4.0  country   [country]           1.0       0.0         0.0
# 4059             4.0  country   [country]           1.0       0.0         0.0
# 4060             3.0  country   [country]           1.0       0.0         0.0
# 4061             4.0  country   [country]           1.0       0.0         0.0
# 4062             4.0  country   [country]           1.0       0.0         0.0
# 4063             3.0  country   [country]           1.0       0.0         0.0
# 4064             3.0  country   [country]           1.0       0.0         0.0
# 4065             4.0  country   [country]           1.0       0.0         0.0
# 4066             4.0  country   [country]           1.0       0.0         0.0
# 4067             4.0  country   [country]           1.0       0.0         0.0
# 4068             4.0  country   [country]           1.0       0.0         0.0
# 4069             4.0  country   [country]           1.0       0.0         0.0
# 4070             1.0  country   [country]           1.0       0.0         0.0
# 4071             4.0  country   [country]           1.0       0.0         0.0
# 4072             4.0  country   [country]           1.0       0.0         0.0
# 4073             4.0  country   [country]           1.0       0.0         0.0
# 4074             4.0  country   [country]           1.0       0.0         0.0
# 4075             4.0  country   [country]           1.0       0.0         0.0
# 4076             4.0  country   [country]           1.0       0.0         0.0
# 4077             4.0  country   [country]           1.0       0.0         0.0
# 4078             3.0  country   [country]           1.0       0.0         0.0
# ...              ...      ...         ...           ...       ...         ...
# 4083             4.0  country   [country]           1.0       0.0         0.0
# 4084             4.0  country   [country]           1.0       0.0         0.0
# 4085             4.0  country   [country]           1.0       0.0         0.0
# 4086             4.0  country   [country]           1.0       0.0         0.0
# 4087             4.0  country   [country]           1.0       0.0         0.0
# 4088             4.0  country   [country]           1.0       0.0         0.0
# 4089             4.0  country   [country]           1.0       0.0         0.0
# 4090             3.0  country   [country]           1.0       0.0         0.0
# 4091             4.0  country   [country]           1.0       0.0         0.0
# 4092             3.0  country   [country]           1.0       0.0         0.0
# 4093             4.0  country   [country]           1.0       0.0         0.0
# 4094             4.0  country   [country]           1.0       0.0         0.0
# 4095             4.0  country   [country]           1.0       0.0         0.0
# 4096             4.0  country   [country]           1.0       0.0         0.0
# 4097             4.0  country   [country]           1.0       0.0         0.0
# 4098             4.0  country   [country]           1.0       0.0         0.0
# 4099             4.0  country   [country]           1.0       0.0         0.0
# 4100             4.0  country   [country]           1.0       0.0         0.0
# 4101             4.0  country   [country]           1.0       0.0         0.0
# 4102             4.0  country   [country]           1.0       0.0         0.0
# 4103             3.0  country   [country]           1.0       0.0         0.0
# 4104             4.0  country   [country]           1.0       0.0         0.0
# 4105             4.0  country   [country]           1.0       0.0         0.0
# 4106             4.0  country   [country]           1.0       0.0         0.0
# 4107             3.0  country   [country]           1.0       0.0         0.0
# 4108             3.0  country   [country]           1.0       0.0         0.0
# 4109             4.0  country   [country]           1.0       0.0         0.0
# 4110             4.0  country   [country]           1.0       0.0         0.0
# 4111             4.0  country   [country]           1.0       0.0         0.0
# 4112             4.0  country   [country]           1.0       0.0         0.0
#
# [64 rows x 43 columns]

# %%
### Save pre-processed Country File
dfCountry.to_pickle('../data/msongs/out/Country_Preprocessed_1109.p')
